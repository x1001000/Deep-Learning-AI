# %% [markdown]
# # Import Library

# %%
import sys
import tensorflow as tf
import numpy as np
import pandas as pd
import gym
import matplotlib.pyplot as plt

# %% [markdown]
# # Plot Steps in Episode Comparison
# 在CartPole遊戲中step越多代表得到reward越多

# %%
step_result = pd.concat([pd.read_csv('ref/DQN_CartPole.csv'),
                         pd.read_csv('ref/prioritized_DQN_CartPole.csv'),
                         pd.read_csv('ref/dueling_DQN_CartPole.csv')],
                        axis = 1)
step_result.plot()
plt.xlabel('Episode')
plt.ylabel('Steps')
plt.yscale("log")
plt.show()

# %% [markdown]
# # Plot CDF Steps in Episode Comparison
# 在CartPole遊戲中step越多代表得到reward越多

# %%
step_result.cumsum().plot()
plt.xlabel('Episode')
plt.ylabel('CDF Steps')
plt.yscale("log")
plt.show()

# %% [markdown]
# # Prioritized DQN Memory所需要的class

# %%
class SumTree(object):
    """
    This SumTree code is modified version and the original code is from: 
    https://github.com/jaara/AI-blog/blob/master/SumTree.py
    Story the data with it priority in tree and data frameworks.
    """
    data_pointer = 0

    def __init__(self, capacity):
        self.capacity = capacity  # for all priority values
        self.tree = np.zeros(2 * capacity - 1)
        # [--------------Parent nodes-------------][-------leaves to recode priority-------]
        #             size: capacity - 1                       size: capacity
        self.data = np.zeros(capacity, dtype=object)  # for all transitions
        # [--------------data frame-------------]
        #             size: capacity

    def add(self, p, data):
        tree_idx = self.data_pointer + self.capacity - 1
        self.data[self.data_pointer] = data  # update data_frame
        self.update(tree_idx, p)  # update tree_frame

        self.data_pointer += 1
        if self.data_pointer >= self.capacity:  # replace when exceed the capacity
            self.data_pointer = 0

    def update(self, tree_idx, p):
        change = p - self.tree[tree_idx]
        self.tree[tree_idx] = p
        # then propagate the change through tree
        while tree_idx != 0:    # this method is faster than the recursive loop in the reference code
            tree_idx = (tree_idx - 1) // 2
            self.tree[tree_idx] += change

    def get_leaf(self, v):
        """
        Tree structure and array storage:
        Tree index:
             0         -> storing priority sum
            / \
          1     2
         / \   / \
        3   4 5   6    -> storing priority for transitions
        Array type for storing:
        [0,1,2,3,4,5,6]
        """
        parent_idx = 0
        while True:     # the while loop is faster than the method in the reference code
            cl_idx = 2 * parent_idx + 1         # this leaf's left and right kids
            cr_idx = cl_idx + 1
            if cl_idx >= len(self.tree):        # reach bottom, end search
                leaf_idx = parent_idx
                break
            else:       # downward search, always search for a higher priority node
                if v <= self.tree[cl_idx]:
                    parent_idx = cl_idx
                else:
                    v -= self.tree[cl_idx]
                    parent_idx = cr_idx

        data_idx = leaf_idx - self.capacity + 1
        return leaf_idx, self.tree[leaf_idx], self.data[data_idx]

    @property
    def total_p(self):
        return self.tree[0]  # the root


class Memory(object):  # stored as ( s, s_, r, a ) in SumTree
    """
    This SumTree code is modified version and the original code is from:
    https://github.com/jaara/AI-blog/blob/master/Seaquest-DDQN-PER.py
    """
    epsilon = 0.01  # small amount to avoid zero priority
    alpha = 0.6  # [0~1] convert the importance of TD error to priority
    beta = 0.4  # importance-sampling, from initial value increasing to 1
    beta_increment_per_sampling = 0.001
    abs_err_upper = 1.  # clipped abs error

    def __init__(self, capacity):
        self.tree = SumTree(capacity)

    def store(self, transition):
        max_p = np.max(self.tree.tree[-self.tree.capacity:])
        if max_p == 0:
            max_p = self.abs_err_upper
        self.tree.add(max_p, transition)   # set the max p for new p

    def sample(self, n):
        b_idx, b_memory, ISWeights = np.empty((n,), dtype=np.int32), np.empty((n, self.tree.data[0].size)), np.empty((n, 1))
        pri_seg = self.tree.total_p / n       # priority segment
        self.beta = np.min([1., self.beta + self.beta_increment_per_sampling])  # max = 1

        min_prob = np.min(self.tree.tree[-self.tree.capacity:]) / self.tree.total_p     # for later calculate ISweight
        for i in range(n):
            a, b = pri_seg * i, pri_seg * (i + 1)
            v = np.random.uniform(a, b)
            idx, p, data = self.tree.get_leaf(v)
            prob = p / self.tree.total_p
            ISWeights[i, 0] = np.power(prob/min_prob, -self.beta)
            b_idx[i], b_memory[i, :] = idx, data
        return b_idx, b_memory, ISWeights

    def batch_update(self, tree_idx, abs_errors):
        abs_errors += self.epsilon  # convert to abs and avoid 0
        clipped_errors = np.minimum(abs_errors, self.abs_err_upper)
        ps = np.power(clipped_errors, self.alpha)
        for ti, p in zip(tree_idx, ps):
            self.tree.update(ti, p)

# %% [markdown]
# # 定義DeepQLearning
# 請大家將class中function的內容完成。投影片上應該也有答案～

# %%
class DeepQLearning:
    
    def __init__(
        self, 
        n_actions, 
        n_states, 
        dueling,
        prioritized,
        gamma = 0.9, #遠見程度
        epsilon = 0.9,  #保守程度，越大就越容易用Q值大小來採取行動；越小則越容易產生隨機行動
        epsilon_increase = None,
        learning_rate = 0.001, #神經網路的更新率
        memory_size = 50, #####
        batch_size = 32, #####
        nueron_num = 10,
        
    ):
        
        self.dueling = dueling
        self.prioritized = prioritized
        self.n_actions = n_actions
        self.n_states = n_states
        self.gamma = gamma
        self.epsilon_max = epsilon #####
        self.epsilon_increase = epsilon_increase #####
        self.epsilon = 0 if epsilon_increase is not None else epsilon #####
        self.lr = learning_rate
        self.memory_size = memory_size #####
        self.memory_counter = 0 #####
        self.batch_size = batch_size ####
        self.nueron_num = nueron_num
        ##### initialize memory
        if self.prioritized:
            self.memory = Memory(capacity=self.memory_size)
        else:
            self.memory = np.zeros((self.memory_size, n_states * 2 + 2))
        """
        memory用來記錄探索環境所蒐集到的資料用來更新神經網路，從公式Q_target = R(s,a) + max(Q(s_,a))*Gamma
        得知我們需要存取的資訊有s(current state), s_(next state), r(reward), a(action) 因此總共需要 2*n_states
        +2的dimension
        """
        
        tf.reset_default_graph() ## 重新 build graph 需要跑這行
        self.sess = tf.Session() #宣告session
        #輸入current state
        self.state_input = tf.placeholder(shape = [None, self.n_states], 
                                          name = 'input',
                                          dtype = tf.float32)
        #q_target = R(s, action) + Q(s_)*Gamma 
        self.q_target = tf.placeholder(shape = [None, self.n_actions], 
                                       name = 'q_target',
                                       dtype = tf.float32)
        if self.prioritized:
            self.ISWeights = tf.placeholder(shape=[None, 1], name='IS_weights', dtype=tf.float32)
        #搭建神經網路
        if self.dueling:
            with tf.variable_scope('Q_table'):
                self.q_eval = self.build_dueling_network(self.nueron_num, Trainable = True, scope = 'net_eval') 
                self.q_next = self.build_dueling_network(self.nueron_num, Trainable = False, scope = 'net_target') ##### 利用另外一個參數較舊的神經網路來給出下一步的q值並計算q_target
        else:
            with tf.variable_scope('Q_table'):
                self.q_eval = self.build_network(self.nueron_num, Trainable = True, scope = 'net_eval') 
                self.q_next = self.build_network(self.nueron_num, Trainable = False, scope = 'net_target') ##### 利用另外一個參數較舊的神經網路來給出下一步的q值並計算q_target

        #管理神經網路的parameters
        self.Qnet_eval_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Q_table/net_eval')
        self.Qnet_target_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Q_table/net_target') #####
        #更新舊神經網路的參數
        self.replace_net_params = [tf.assign(old, new) for old, new in zip(self.Qnet_target_params, self.Qnet_eval_params)]
        
        #計算q_target和q_eval的mse來更新神經網路的參數
        if self.prioritized:
            self.abs_errors = tf.reduce_sum(tf.abs(self.q_target - self.q_eval), axis=1)    # for updating Sumtree
            self.loss = tf.reduce_mean(self.ISWeights * tf.squared_difference(self.q_target, self.q_eval))
        else:
            self.loss = tf.reduce_mean(tf.squared_difference(self.q_target, self.q_eval))
        
        self.train = tf.train.RMSPropOptimizer(self.lr).minimize(self.loss, var_list=self.Qnet_eval_params)
        
        self.sess.run(tf.global_variables_initializer()) #將神經網路初始化
    
    def write_memory(self, current_state, next_state, reward, action): #####
        if self.prioritized:    # prioritized replay
            env_info = np.concatenate([current_state, next_state, [reward], [action]]) 
            self.memory.store(env_info)
        else:
            env_info = np.concatenate([current_state, next_state, [reward], [action]]) 
            save_index = self.memory_counter%self.memory_size
            self.memory[save_index, :] = env_info
            self.memory_counter+=1
            if self.memory_counter%self.memory_size == 0:
                self.memory_counter = self.memory_size

    
    def build_network(self, neuron_num, Trainable, scope): 
        with tf.variable_scope(scope):
            init_w = tf.random_normal_initializer(0., 0.3)
            init_b = tf.constant_initializer(0.1)
            
            x_h1 = tf.layers.dense(inputs = self.state_input, units = neuron_num, activation = tf.nn.tanh, kernel_initializer=init_w, bias_initializer=init_b, trainable=Trainable) 
            
            x_h2 = tf.layers.dense(inputs = x_h1, units = neuron_num, activation = tf.nn.tanh, kernel_initializer=init_w, bias_initializer=init_b, trainable=Trainable)  
            
            output = tf.layers.dense(inputs = x_h2, units = self.n_actions, kernel_initializer=init_w, bias_initializer=init_b, trainable=Trainable)
        
        return output #輸出‘不同動作’對應的Q值 
    
    def build_dueling_network(self, neuron_num, Trainable, scope):      
        with tf.variable_scope(scope):
            init_w = tf.random_normal_initializer(0., 0.3)
            init_b = tf.constant_initializer(0.1)
            h1 = tf.layers.dense(inputs = self.state_input, 
                                       units = neuron_num, 
                                       activation = tf.nn.tanh, 
                                       kernel_initializer=init_w, 
                                       bias_initializer=init_b, 
                                       trainable=Trainable) 
            #build state value network
            with tf.variable_scope('state_value'):
                

                v_h2 = tf.layers.dense(inputs = h1, 
                                       units = neuron_num, 
                                       activation = tf.nn.tanh, 
                                       kernel_initializer=init_w, 
                                       bias_initializer=init_b, 
                                       trainable=Trainable)  

                state_value = tf.layers.dense(inputs = v_h2, 
                                              units = 1, 
                                              kernel_initializer=init_w, 
                                              bias_initializer=init_b, 
                                              trainable=Trainable)
            
            #build advantage network
            with tf.variable_scope('advantage'):
                a_h2 = tf.layers.dense(inputs = h1, 
                                       units = neuron_num, 
                                       activation = tf.nn.tanh, 
                                       kernel_initializer=init_w, 
                                       bias_initializer=init_b, 
                                       trainable=Trainable)  

                advantage = tf.layers.dense(inputs = a_h2, 
                                            units = self.n_actions, 
                                            kernel_initializer=init_w, 
                                            bias_initializer=init_b, 
                                            trainable=Trainable)
            #將state value和advantage相加
            output = state_value + (advantage - tf.reduce_mean(advantage, axis=1, keep_dims=True))
            
        return output #輸出‘不同動作’對應的Q值 
            
    def choose_action(self, current_state):
        if np.random.uniform() < self.epsilon: 
            #選擇產生估計Q值較大的行動
            q_eval = self.sess.run(self.q_eval, feed_dict={self.state_input: current_state[np.newaxis, :]})
            self.action = np.argmax(q_eval)
        else:
            #採取隨機行動
            self.action = np.random.randint(0, self.n_actions)
          
   
        return self.action
    
    def learn(self, current_state, reward, next_state, update_params): #####
        
        if update_params: #####
            self.sess.run(self.replace_net_params)
            #print('update parameters')
        
        #####從記憶中抽取過去的經驗來做更新
        if self.prioritized:
            tree_idx, past_experience, ISWeights = self.memory.sample(self.batch_size)
        else:    
            if self.memory_counter > self.memory_size:
                sample_index = np.random.choice(self.memory_size, size=self.batch_size)
            else:
                sample_index = np.random.choice(self.memory_counter, size=self.batch_size)
            past_experience = self.memory[sample_index, :]
        
        current_state = past_experience[:, 0:self.n_states]
        next_state = past_experience[:, self.n_states:self.n_states*2]
        reward = past_experience[:, self.n_states*2]
        action = past_experience[:, self.n_states*2+1].astype(int)
        index = np.arange(self.batch_size)

        #算出實際q值並用此更新神經網路參數
        q_eval = self.sess.run(self.q_eval, feed_dict={self.state_input: current_state})
        q_next = self.sess.run(self.q_next, feed_dict={self.state_input: next_state})
        q_target = q_eval.copy()
        q_target[index, action] = reward + self.gamma*np.max(q_next, axis=1)
        if self.prioritized:
            _, abs_errors, self.cost = self.sess.run([self.train, self.abs_errors, self.loss],\
                                         feed_dict={self.state_input: current_state,\
                                                    self.q_target: q_target,\
                                                    self.ISWeights: ISWeights})
            self.memory.batch_update(tree_idx, abs_errors)   # update priority
        else:    
            _, self.cost = self.sess.run([self.train, self.loss], feed_dict={self.state_input: current_state,\
                                                                                self.q_target: q_target})        # increasing epsilon
        self.epsilon = self.epsilon + self.epsilon_increase if self.epsilon < self.epsilon_max else self.epsilon_max  
        
    def model_save(self, model_name):
        
        saver = tf.train.Saver()
        saver.save(self.sess, "saved_models/{}.ckpt".format(model_name))
    
    def model_restore(self, model_name):
        
        saver = tf.train.Saver()
        saver.restore(self.sess, "saved_models/{}.ckpt".format(model_name))

# %% [markdown]
# # Define Training的環境和步驟

# %%
def training(save_model, model_name):
    step_record = []
    reward_record = []
    learn_count = 0
    update_count = 0
    for episode in range(2000):
        # initial environment並給出起始的state
        current_state = env.reset()
        step = 0
        total_reward = 0
        while True:
            # 產生環境視窗
            env.render()

            # 根據現在的狀態選擇動作
            action = RL.choose_action(current_state)

            # 產生動作和環境互動後產生下一個狀態、獎勵值及遊戲是否結束
            next_state, reward, done, _ = env.step(action)
            
            # 調整reward
            if done:
                reward = -10
            else:
                reward = 0
            #怕玩太久，強迫結束
            if step ==500:
                done = True
            
            total_reward+=reward
            # 將資訊存至記憶體中以便進行experience replay
            RL.write_memory(current_state, next_state, reward, action)

            # 進行學習
            if learn_count <= 1000:
                learn_count+=1
            else:
                #進行參數更新
                if update_count==300:
                    update = True
                    update_count =0
                else:
                    update = False
                    update_count+=1
                
                RL.learn(current_state, reward, next_state, update)
            
            # break while loop when end of this episode
            if done:
                mean_reward = total_reward/step
                print('episode:{} steps:{} total reward:{} epsilon:{}'.format(episode, step, \
                       total_reward, RL.epsilon))
                step_record.append(step)
                reward_record.append(total_reward)
                break
            current_state = next_state
            step += 1

    # end of game
    if save_model:
        RL.model_save(model_name)
    print('game over')
    env.close()
    return step_record, reward_record

# %%
step_result = []
reward_result = []
env = gym.make('CartPole-v0')
env = env.unwrapped
env.seed(1)

RL = DeepQLearning( n_actions = 2, 
                    n_states = 4,
                    gamma = 0.99,
                    epsilon = 0.95,
                    epsilon_increase = 0.001,
                    learning_rate = 0.001,
                    memory_size = 10000,
                    batch_size = 32,
                    nueron_num = 10,
                    dueling = True,
                    prioritized = False
                    )
step_record, reward_record = training(save_model = True, model_name='cartpole_Prioritized_dqn')
step_result.append(pd.DataFrame(step_record))
reward_result.append(pd.DataFrame(reward_record))
# Out:
# episode:0 steps:44 total reward:-10 epsilon:0
# episode:1 steps:15 total reward:-10 epsilon:0
# episode:2 steps:11 total reward:-10 epsilon:0
# episode:3 steps:14 total reward:-10 epsilon:0
# episode:4 steps:35 total reward:-10 epsilon:0
# episode:5 steps:15 total reward:-10 epsilon:0
# episode:6 steps:23 total reward:-10 epsilon:0
# episode:7 steps:8 total reward:-10 epsilon:0
# episode:8 steps:38 total reward:-10 epsilon:0
# episode:9 steps:16 total reward:-10 epsilon:0
# episode:10 steps:11 total reward:-10 epsilon:0
# episode:11 steps:10 total reward:-10 epsilon:0
# episode:12 steps:19 total reward:-10 epsilon:0
# episode:13 steps:30 total reward:-10 epsilon:0
# episode:14 steps:23 total reward:-10 epsilon:0
# episode:15 steps:22 total reward:-10 epsilon:0
# episode:16 steps:9 total reward:-10 epsilon:0
# episode:17 steps:11 total reward:-10 epsilon:0
# episode:18 steps:12 total reward:-10 epsilon:0
# episode:19 steps:10 total reward:-10 epsilon:0
# episode:20 steps:15 total reward:-10 epsilon:0
# episode:21 steps:29 total reward:-10 epsilon:0
# episode:22 steps:19 total reward:-10 epsilon:0
# episode:23 steps:43 total reward:-10 epsilon:0
# episode:24 steps:40 total reward:-10 epsilon:0
# episode:25 steps:13 total reward:-10 epsilon:0
# episode:26 steps:27 total reward:-10 epsilon:0
# episode:27 steps:11 total reward:-10 epsilon:0
# episode:28 steps:15 total reward:-10 epsilon:0
# episode:29 steps:23 total reward:-10 epsilon:0
# episode:30 steps:20 total reward:-10 epsilon:0
# episode:31 steps:32 total reward:-10 epsilon:0
# episode:32 steps:33 total reward:-10 epsilon:0
# episode:33 steps:11 total reward:-10 epsilon:0
# episode:34 steps:22 total reward:-10 epsilon:0
# episode:35 steps:28 total reward:-10 epsilon:0
# episode:36 steps:41 total reward:-10 epsilon:0
# episode:37 steps:12 total reward:-10 epsilon:0
# episode:38 steps:24 total reward:-10 epsilon:0
# episode:39 steps:12 total reward:-10 epsilon:0
# episode:40 steps:26 total reward:-10 epsilon:0
# episode:41 steps:11 total reward:-10 epsilon:0
# episode:42 steps:23 total reward:-10 epsilon:0
# episode:43 steps:22 total reward:-10 epsilon:0
# episode:44 steps:13 total reward:-10 epsilon:0
# episode:45 steps:13 total reward:-10 epsilon:0
# episode:46 steps:21 total reward:-10 epsilon:0.02100000000000001
# episode:47 steps:39 total reward:-10 epsilon:0.06100000000000005
# episode:48 steps:34 total reward:-10 epsilon:0.09600000000000007
# episode:49 steps:10 total reward:-10 epsilon:0.10700000000000008
# episode:50 steps:17 total reward:-10 epsilon:0.12500000000000008
# episode:51 steps:32 total reward:-10 epsilon:0.1580000000000001
# episode:52 steps:20 total reward:-10 epsilon:0.17900000000000013
# episode:53 steps:13 total reward:-10 epsilon:0.19300000000000014
# episode:54 steps:8 total reward:-10 epsilon:0.20200000000000015
# episode:55 steps:10 total reward:-10 epsilon:0.21300000000000016
# episode:56 steps:26 total reward:-10 epsilon:0.24000000000000019
# episode:57 steps:13 total reward:-10 epsilon:0.25400000000000017
# episode:58 steps:20 total reward:-10 epsilon:0.2750000000000002
# episode:59 steps:13 total reward:-10 epsilon:0.2890000000000002
# episode:60 steps:11 total reward:-10 epsilon:0.3010000000000002
# episode:61 steps:13 total reward:-10 epsilon:0.3150000000000002
# episode:62 steps:18 total reward:-10 epsilon:0.33400000000000024
# episode:63 steps:9 total reward:-10 epsilon:0.34400000000000025
# episode:64 steps:19 total reward:-10 epsilon:0.36400000000000027
# episode:65 steps:19 total reward:-10 epsilon:0.3840000000000003
# episode:66 steps:12 total reward:-10 epsilon:0.3970000000000003
# episode:67 steps:9 total reward:-10 epsilon:0.4070000000000003
# episode:68 steps:21 total reward:-10 epsilon:0.4290000000000003
# episode:69 steps:28 total reward:-10 epsilon:0.45800000000000035
# episode:70 steps:9 total reward:-10 epsilon:0.46800000000000036
# episode:71 steps:10 total reward:-10 epsilon:0.47900000000000037
# episode:72 steps:10 total reward:-10 epsilon:0.4900000000000004
# episode:73 steps:11 total reward:-10 epsilon:0.5020000000000003
# episode:74 steps:11 total reward:-10 epsilon:0.5140000000000003
# episode:75 steps:25 total reward:-10 epsilon:0.5400000000000004
# episode:76 steps:12 total reward:-10 epsilon:0.5530000000000004
# episode:77 steps:12 total reward:-10 epsilon:0.5660000000000004
# episode:78 steps:7 total reward:-10 epsilon:0.5740000000000004
# episode:79 steps:8 total reward:-10 epsilon:0.5830000000000004
# episode:80 steps:12 total reward:-10 epsilon:0.5960000000000004
# episode:81 steps:9 total reward:-10 epsilon:0.6060000000000004
# episode:82 steps:9 total reward:-10 epsilon:0.6160000000000004
# episode:83 steps:8 total reward:-10 epsilon:0.6250000000000004
# episode:84 steps:9 total reward:-10 epsilon:0.6350000000000005
# episode:85 steps:11 total reward:-10 epsilon:0.6470000000000005
# episode:86 steps:10 total reward:-10 epsilon:0.6580000000000005
# episode:87 steps:12 total reward:-10 epsilon:0.6710000000000005
# episode:88 steps:9 total reward:-10 epsilon:0.6810000000000005
# episode:89 steps:9 total reward:-10 epsilon:0.6910000000000005
# episode:90 steps:11 total reward:-10 epsilon:0.7030000000000005
# episode:91 steps:9 total reward:-10 epsilon:0.7130000000000005
# episode:92 steps:9 total reward:-10 epsilon:0.7230000000000005
# episode:93 steps:8 total reward:-10 epsilon:0.7320000000000005
# episode:94 steps:9 total reward:-10 epsilon:0.7420000000000005
# episode:95 steps:12 total reward:-10 epsilon:0.7550000000000006
# episode:96 steps:10 total reward:-10 epsilon:0.7660000000000006
# episode:97 steps:8 total reward:-10 epsilon:0.7750000000000006
# episode:98 steps:11 total reward:-10 epsilon:0.7870000000000006
# episode:99 steps:10 total reward:-10 epsilon:0.7980000000000006
# episode:100 steps:8 total reward:-10 epsilon:0.8070000000000006
# episode:101 steps:11 total reward:-10 epsilon:0.8190000000000006
# episode:102 steps:9 total reward:-10 epsilon:0.8290000000000006
# episode:103 steps:13 total reward:-10 epsilon:0.8430000000000006
# episode:104 steps:11 total reward:-10 epsilon:0.8550000000000006
# episode:105 steps:11 total reward:-10 epsilon:0.8670000000000007
# episode:106 steps:8 total reward:-10 epsilon:0.8760000000000007
# episode:107 steps:9 total reward:-10 epsilon:0.8860000000000007
# episode:108 steps:8 total reward:-10 epsilon:0.8950000000000007
# episode:109 steps:10 total reward:-10 epsilon:0.9060000000000007
# episode:110 steps:10 total reward:-10 epsilon:0.9170000000000007
# episode:111 steps:13 total reward:-10 epsilon:0.9310000000000007
# episode:112 steps:9 total reward:-10 epsilon:0.9410000000000007
# episode:113 steps:10 total reward:-10 epsilon:0.95
# episode:114 steps:16 total reward:-10 epsilon:0.95
# episode:115 steps:43 total reward:-10 epsilon:0.95
# episode:116 steps:31 total reward:-10 epsilon:0.95
# episode:117 steps:68 total reward:-10 epsilon:0.95
# episode:118 steps:63 total reward:-10 epsilon:0.95
# episode:119 steps:79 total reward:-10 epsilon:0.95
# episode:120 steps:39 total reward:-10 epsilon:0.95
# episode:121 steps:25 total reward:-10 epsilon:0.95
# episode:122 steps:22 total reward:-10 epsilon:0.95
# episode:123 steps:21 total reward:-10 epsilon:0.95
# episode:124 steps:27 total reward:-10 epsilon:0.95
# episode:125 steps:20 total reward:-10 epsilon:0.95
# episode:126 steps:23 total reward:-10 epsilon:0.95
# episode:127 steps:35 total reward:-10 epsilon:0.95
# episode:128 steps:31 total reward:-10 epsilon:0.95
# episode:129 steps:15 total reward:-10 epsilon:0.95
# episode:130 steps:15 total reward:-10 epsilon:0.95
# episode:131 steps:11 total reward:-10 epsilon:0.95
# episode:132 steps:11 total reward:-10 epsilon:0.95
# episode:133 steps:17 total reward:-10 epsilon:0.95
# episode:134 steps:12 total reward:-10 epsilon:0.95
# episode:135 steps:10 total reward:-10 epsilon:0.95
# episode:136 steps:9 total reward:-10 epsilon:0.95
# episode:137 steps:9 total reward:-10 epsilon:0.95
# episode:138 steps:7 total reward:-10 epsilon:0.95
# episode:139 steps:9 total reward:-10 epsilon:0.95
# episode:140 steps:8 total reward:-10 epsilon:0.95
# episode:141 steps:8 total reward:-10 epsilon:0.95
# episode:142 steps:13 total reward:-10 epsilon:0.95
# episode:143 steps:11 total reward:-10 epsilon:0.95
# episode:144 steps:11 total reward:-10 epsilon:0.95
# episode:145 steps:10 total reward:-10 epsilon:0.95
# episode:146 steps:8 total reward:-10 epsilon:0.95
# episode:147 steps:13 total reward:-10 epsilon:0.95
# episode:148 steps:8 total reward:-10 epsilon:0.95
# episode:149 steps:10 total reward:-10 epsilon:0.95
# episode:150 steps:9 total reward:-10 epsilon:0.95
# episode:151 steps:8 total reward:-10 epsilon:0.95
# episode:152 steps:9 total reward:-10 epsilon:0.95
# episode:153 steps:8 total reward:-10 epsilon:0.95
# episode:154 steps:9 total reward:-10 epsilon:0.95
# episode:155 steps:8 total reward:-10 epsilon:0.95
# episode:156 steps:9 total reward:-10 epsilon:0.95
# episode:157 steps:10 total reward:-10 epsilon:0.95
# episode:158 steps:9 total reward:-10 epsilon:0.95
# episode:159 steps:8 total reward:-10 epsilon:0.95
# episode:160 steps:9 total reward:-10 epsilon:0.95
# episode:161 steps:7 total reward:-10 epsilon:0.95
# episode:162 steps:9 total reward:-10 epsilon:0.95
# episode:163 steps:8 total reward:-10 epsilon:0.95
# episode:164 steps:8 total reward:-10 epsilon:0.95
# episode:165 steps:9 total reward:-10 epsilon:0.95
# episode:166 steps:9 total reward:-10 epsilon:0.95
# episode:167 steps:10 total reward:-10 epsilon:0.95
# episode:168 steps:9 total reward:-10 epsilon:0.95
# episode:169 steps:10 total reward:-10 epsilon:0.95
# episode:170 steps:10 total reward:-10 epsilon:0.95
# episode:171 steps:9 total reward:-10 epsilon:0.95
# episode:172 steps:7 total reward:-10 epsilon:0.95
# episode:173 steps:9 total reward:-10 epsilon:0.95
# episode:174 steps:8 total reward:-10 epsilon:0.95
# episode:175 steps:9 total reward:-10 epsilon:0.95
# episode:176 steps:8 total reward:-10 epsilon:0.95
# episode:177 steps:9 total reward:-10 epsilon:0.95
# episode:178 steps:9 total reward:-10 epsilon:0.95
# episode:179 steps:9 total reward:-10 epsilon:0.95
# episode:180 steps:8 total reward:-10 epsilon:0.95
# episode:181 steps:8 total reward:-10 epsilon:0.95
# episode:182 steps:9 total reward:-10 epsilon:0.95
# episode:183 steps:8 total reward:-10 epsilon:0.95
# episode:184 steps:8 total reward:-10 epsilon:0.95
# episode:185 steps:8 total reward:-10 epsilon:0.95
# episode:186 steps:7 total reward:-10 epsilon:0.95
# episode:187 steps:9 total reward:-10 epsilon:0.95
# episode:188 steps:9 total reward:-10 epsilon:0.95
# episode:189 steps:13 total reward:-10 epsilon:0.95
# episode:190 steps:9 total reward:-10 epsilon:0.95
# episode:191 steps:10 total reward:-10 epsilon:0.95
# episode:192 steps:10 total reward:-10 epsilon:0.95
# episode:193 steps:14 total reward:-10 epsilon:0.95
# episode:194 steps:9 total reward:-10 epsilon:0.95
# episode:195 steps:13 total reward:-10 epsilon:0.95
# episode:196 steps:10 total reward:-10 epsilon:0.95
# episode:197 steps:10 total reward:-10 epsilon:0.95
# episode:198 steps:10 total reward:-10 epsilon:0.95
# episode:199 steps:12 total reward:-10 epsilon:0.95
# episode:200 steps:12 total reward:-10 epsilon:0.95
# episode:201 steps:8 total reward:-10 epsilon:0.95
# episode:202 steps:8 total reward:-10 epsilon:0.95
# episode:203 steps:7 total reward:-10 epsilon:0.95
# episode:204 steps:9 total reward:-10 epsilon:0.95
# episode:205 steps:8 total reward:-10 epsilon:0.95
# episode:206 steps:8 total reward:-10 epsilon:0.95
# episode:207 steps:11 total reward:-10 epsilon:0.95
# episode:208 steps:7 total reward:-10 epsilon:0.95
# episode:209 steps:12 total reward:-10 epsilon:0.95
# episode:210 steps:13 total reward:-10 epsilon:0.95
# episode:211 steps:9 total reward:-10 epsilon:0.95
# episode:212 steps:9 total reward:-10 epsilon:0.95
# episode:213 steps:7 total reward:-10 epsilon:0.95
# episode:214 steps:8 total reward:-10 epsilon:0.95
# episode:215 steps:11 total reward:-10 epsilon:0.95
# episode:216 steps:18 total reward:-10 epsilon:0.95
# episode:217 steps:10 total reward:-10 epsilon:0.95
# episode:218 steps:15 total reward:-10 epsilon:0.95
# episode:219 steps:19 total reward:-10 epsilon:0.95
# episode:220 steps:15 total reward:-10 epsilon:0.95
# episode:221 steps:17 total reward:-10 epsilon:0.95
# episode:222 steps:11 total reward:-10 epsilon:0.95
# episode:223 steps:15 total reward:-10 epsilon:0.95
# episode:224 steps:23 total reward:-10 epsilon:0.95
# episode:225 steps:12 total reward:-10 epsilon:0.95
# episode:226 steps:15 total reward:-10 epsilon:0.95
# episode:227 steps:13 total reward:-10 epsilon:0.95
# episode:228 steps:14 total reward:-10 epsilon:0.95
# episode:229 steps:9 total reward:-10 epsilon:0.95
# episode:230 steps:11 total reward:-10 epsilon:0.95
# episode:231 steps:12 total reward:-10 epsilon:0.95
# episode:232 steps:9 total reward:-10 epsilon:0.95
# episode:233 steps:12 total reward:-10 epsilon:0.95
# episode:234 steps:12 total reward:-10 epsilon:0.95
# episode:235 steps:14 total reward:-10 epsilon:0.95
# episode:236 steps:21 total reward:-10 epsilon:0.95
# episode:237 steps:15 total reward:-10 epsilon:0.95
# episode:238 steps:27 total reward:-10 epsilon:0.95
# episode:239 steps:19 total reward:-10 epsilon:0.95
# episode:240 steps:22 total reward:-10 epsilon:0.95
# episode:241 steps:21 total reward:-10 epsilon:0.95
# episode:242 steps:10 total reward:-10 epsilon:0.95
# episode:243 steps:13 total reward:-10 epsilon:0.95
# episode:244 steps:25 total reward:-10 epsilon:0.95
# episode:245 steps:34 total reward:-10 epsilon:0.95
# episode:246 steps:37 total reward:-10 epsilon:0.95
# episode:247 steps:66 total reward:-10 epsilon:0.95
# episode:248 steps:45 total reward:-10 epsilon:0.95
# episode:249 steps:30 total reward:-10 epsilon:0.95
# episode:250 steps:40 total reward:-10 epsilon:0.95
# episode:251 steps:64 total reward:-10 epsilon:0.95
# episode:252 steps:34 total reward:-10 epsilon:0.95
# episode:253 steps:31 total reward:-10 epsilon:0.95
# episode:254 steps:40 total reward:-10 epsilon:0.95
# episode:255 steps:33 total reward:-10 epsilon:0.95
# episode:256 steps:40 total reward:-10 epsilon:0.95
# episode:257 steps:24 total reward:-10 epsilon:0.95
# episode:258 steps:21 total reward:-10 epsilon:0.95
# episode:259 steps:10 total reward:-10 epsilon:0.95
# episode:260 steps:31 total reward:-10 epsilon:0.95
# episode:261 steps:40 total reward:-10 epsilon:0.95
# episode:262 steps:51 total reward:-10 epsilon:0.95
# episode:263 steps:41 total reward:-10 epsilon:0.95
# episode:264 steps:14 total reward:-10 epsilon:0.95
# episode:265 steps:13 total reward:-10 epsilon:0.95
# episode:266 steps:11 total reward:-10 epsilon:0.95
# episode:267 steps:32 total reward:-10 epsilon:0.95
# episode:268 steps:39 total reward:-10 epsilon:0.95
# episode:269 steps:59 total reward:-10 epsilon:0.95
# episode:270 steps:54 total reward:-10 epsilon:0.95
# episode:271 steps:71 total reward:-10 epsilon:0.95
# episode:272 steps:23 total reward:-10 epsilon:0.95
# episode:273 steps:11 total reward:-10 epsilon:0.95
# episode:274 steps:20 total reward:-10 epsilon:0.95
# episode:275 steps:48 total reward:-10 epsilon:0.95
# episode:276 steps:76 total reward:-10 epsilon:0.95
# episode:277 steps:43 total reward:-10 epsilon:0.95
# episode:278 steps:75 total reward:-10 epsilon:0.95
# episode:279 steps:64 total reward:-10 epsilon:0.95
# episode:280 steps:68 total reward:-10 epsilon:0.95
# episode:281 steps:95 total reward:-10 epsilon:0.95
# episode:282 steps:37 total reward:-10 epsilon:0.95
# episode:283 steps:33 total reward:-10 epsilon:0.95
# episode:284 steps:59 total reward:-10 epsilon:0.95
# episode:285 steps:46 total reward:-10 epsilon:0.95
# episode:286 steps:38 total reward:-10 epsilon:0.95
# episode:287 steps:78 total reward:-10 epsilon:0.95
# episode:288 steps:167 total reward:-10 epsilon:0.95
# episode:289 steps:76 total reward:-10 epsilon:0.95
# episode:290 steps:83 total reward:-10 epsilon:0.95
# episode:291 steps:163 total reward:-10 epsilon:0.95
# episode:292 steps:80 total reward:-10 epsilon:0.95
# episode:293 steps:99 total reward:-10 epsilon:0.95
# episode:294 steps:109 total reward:-10 epsilon:0.95
# episode:295 steps:88 total reward:-10 epsilon:0.95
# episode:296 steps:87 total reward:-10 epsilon:0.95
# episode:297 steps:86 total reward:-10 epsilon:0.95
# episode:298 steps:72 total reward:-10 epsilon:0.95
# episode:299 steps:83 total reward:-10 epsilon:0.95
# episode:300 steps:81 total reward:-10 epsilon:0.95
# episode:301 steps:61 total reward:-10 epsilon:0.95
# episode:302 steps:64 total reward:-10 epsilon:0.95
# episode:303 steps:109 total reward:-10 epsilon:0.95
# episode:304 steps:85 total reward:-10 epsilon:0.95
# episode:305 steps:75 total reward:-10 epsilon:0.95
# episode:306 steps:66 total reward:-10 epsilon:0.95
# episode:307 steps:74 total reward:-10 epsilon:0.95
# episode:308 steps:96 total reward:-10 epsilon:0.95
# episode:309 steps:92 total reward:-10 epsilon:0.95
# episode:310 steps:87 total reward:-10 epsilon:0.95
# episode:311 steps:73 total reward:-10 epsilon:0.95
# episode:312 steps:94 total reward:-10 epsilon:0.95
# episode:313 steps:86 total reward:-10 epsilon:0.95
# episode:314 steps:84 total reward:-10 epsilon:0.95
# episode:315 steps:78 total reward:-10 epsilon:0.95
# episode:316 steps:83 total reward:-10 epsilon:0.95
# episode:317 steps:80 total reward:-10 epsilon:0.95
# episode:318 steps:78 total reward:-10 epsilon:0.95
# episode:319 steps:131 total reward:-10 epsilon:0.95
# episode:320 steps:90 total reward:-10 epsilon:0.95
# episode:321 steps:108 total reward:-10 epsilon:0.95
# episode:322 steps:90 total reward:-10 epsilon:0.95
# episode:323 steps:96 total reward:-10 epsilon:0.95
# episode:324 steps:360 total reward:-10 epsilon:0.95
# episode:325 steps:79 total reward:-10 epsilon:0.95
# episode:326 steps:104 total reward:-10 epsilon:0.95
# episode:327 steps:86 total reward:-10 epsilon:0.95
# episode:328 steps:96 total reward:-10 epsilon:0.95
# episode:329 steps:123 total reward:-10 epsilon:0.95
# episode:330 steps:114 total reward:-10 epsilon:0.95
# episode:331 steps:110 total reward:-10 epsilon:0.95
# episode:332 steps:107 total reward:-10 epsilon:0.95
# episode:333 steps:205 total reward:-10 epsilon:0.95
# episode:334 steps:103 total reward:-10 epsilon:0.95
# episode:335 steps:259 total reward:-10 epsilon:0.95
# episode:336 steps:174 total reward:-10 epsilon:0.95
# episode:337 steps:270 total reward:-10 epsilon:0.95
# episode:338 steps:204 total reward:-10 epsilon:0.95
# episode:339 steps:174 total reward:-10 epsilon:0.95
# episode:340 steps:120 total reward:-10 epsilon:0.95
# episode:341 steps:124 total reward:-10 epsilon:0.95
# episode:342 steps:129 total reward:-10 epsilon:0.95
# episode:343 steps:129 total reward:-10 epsilon:0.95
# episode:344 steps:177 total reward:-10 epsilon:0.95
# episode:345 steps:168 total reward:-10 epsilon:0.95
# episode:346 steps:148 total reward:-10 epsilon:0.95
# episode:347 steps:211 total reward:-10 epsilon:0.95
# episode:348 steps:340 total reward:-10 epsilon:0.95
# episode:349 steps:174 total reward:-10 epsilon:0.95
# episode:350 steps:258 total reward:-10 epsilon:0.95
# episode:351 steps:153 total reward:-10 epsilon:0.95
# episode:352 steps:162 total reward:-10 epsilon:0.95
# episode:353 steps:144 total reward:-10 epsilon:0.95
# episode:354 steps:164 total reward:-10 epsilon:0.95
# episode:355 steps:165 total reward:-10 epsilon:0.95
# episode:356 steps:442 total reward:-10 epsilon:0.95
# episode:357 steps:213 total reward:-10 epsilon:0.95
# episode:358 steps:202 total reward:-10 epsilon:0.95
# episode:359 steps:143 total reward:-10 epsilon:0.95
# episode:360 steps:166 total reward:-10 epsilon:0.95
# episode:361 steps:362 total reward:-10 epsilon:0.95
# episode:362 steps:191 total reward:-10 epsilon:0.95
# episode:363 steps:213 total reward:-10 epsilon:0.95
# episode:364 steps:207 total reward:-10 epsilon:0.95
# episode:365 steps:169 total reward:-10 epsilon:0.95
# episode:366 steps:175 total reward:-10 epsilon:0.95
# episode:367 steps:263 total reward:-10 epsilon:0.95
# episode:368 steps:350 total reward:-10 epsilon:0.95
# episode:369 steps:207 total reward:-10 epsilon:0.95
# episode:370 steps:239 total reward:-10 epsilon:0.95
# episode:371 steps:215 total reward:-10 epsilon:0.95
# episode:372 steps:261 total reward:-10 epsilon:0.95
# episode:373 steps:167 total reward:-10 epsilon:0.95
# episode:374 steps:211 total reward:-10 epsilon:0.95
# episode:375 steps:284 total reward:-10 epsilon:0.95
# episode:376 steps:303 total reward:-10 epsilon:0.95
# episode:377 steps:226 total reward:-10 epsilon:0.95
# episode:378 steps:246 total reward:-10 epsilon:0.95
# episode:379 steps:206 total reward:-10 epsilon:0.95
# episode:380 steps:210 total reward:-10 epsilon:0.95
# episode:381 steps:326 total reward:-10 epsilon:0.95
# episode:382 steps:303 total reward:-10 epsilon:0.95
# episode:383 steps:274 total reward:-10 epsilon:0.95
# episode:384 steps:223 total reward:-10 epsilon:0.95
# episode:385 steps:267 total reward:-10 epsilon:0.95
# episode:386 steps:198 total reward:-10 epsilon:0.95
# episode:387 steps:220 total reward:-10 epsilon:0.95
# episode:388 steps:225 total reward:-10 epsilon:0.95
# episode:389 steps:177 total reward:-10 epsilon:0.95
# episode:390 steps:222 total reward:-10 epsilon:0.95
# episode:391 steps:276 total reward:-10 epsilon:0.95
# episode:392 steps:224 total reward:-10 epsilon:0.95
# episode:393 steps:300 total reward:-10 epsilon:0.95
# episode:394 steps:204 total reward:-10 epsilon:0.95
# episode:395 steps:220 total reward:-10 epsilon:0.95
# episode:396 steps:469 total reward:-10 epsilon:0.95
# episode:397 steps:202 total reward:-10 epsilon:0.95
# episode:398 steps:208 total reward:-10 epsilon:0.95
# episode:399 steps:255 total reward:-10 epsilon:0.95
# episode:400 steps:209 total reward:-10 epsilon:0.95
# episode:401 steps:257 total reward:-10 epsilon:0.95
# episode:402 steps:207 total reward:-10 epsilon:0.95
# episode:403 steps:193 total reward:-10 epsilon:0.95
# episode:404 steps:231 total reward:-10 epsilon:0.95
# episode:405 steps:310 total reward:-10 epsilon:0.95
# episode:406 steps:277 total reward:-10 epsilon:0.95
# episode:407 steps:280 total reward:-10 epsilon:0.95
# episode:408 steps:291 total reward:-10 epsilon:0.95
# episode:409 steps:276 total reward:-10 epsilon:0.95
# episode:410 steps:300 total reward:-10 epsilon:0.95
# episode:411 steps:253 total reward:-10 epsilon:0.95
# episode:412 steps:251 total reward:-10 epsilon:0.95
# episode:413 steps:317 total reward:-10 epsilon:0.95
# episode:414 steps:308 total reward:-10 epsilon:0.95
# episode:415 steps:230 total reward:-10 epsilon:0.95
# episode:416 steps:283 total reward:-10 epsilon:0.95
# episode:417 steps:318 total reward:-10 epsilon:0.95
# episode:418 steps:298 total reward:-10 epsilon:0.95
# episode:419 steps:221 total reward:-10 epsilon:0.95
# episode:420 steps:229 total reward:-10 epsilon:0.95
# episode:421 steps:263 total reward:-10 epsilon:0.95
# episode:422 steps:249 total reward:-10 epsilon:0.95
# episode:423 steps:263 total reward:-10 epsilon:0.95
# episode:424 steps:237 total reward:-10 epsilon:0.95
# episode:425 steps:256 total reward:-10 epsilon:0.95
# episode:426 steps:268 total reward:-10 epsilon:0.95
# episode:427 steps:279 total reward:-10 epsilon:0.95
# episode:428 steps:260 total reward:-10 epsilon:0.95
# episode:429 steps:265 total reward:-10 epsilon:0.95
# episode:430 steps:228 total reward:-10 epsilon:0.95
# episode:431 steps:254 total reward:-10 epsilon:0.95
# episode:432 steps:279 total reward:-10 epsilon:0.95
# episode:433 steps:231 total reward:-10 epsilon:0.95
# episode:434 steps:270 total reward:-10 epsilon:0.95
# episode:435 steps:303 total reward:-10 epsilon:0.95
# episode:436 steps:276 total reward:-10 epsilon:0.95
# episode:437 steps:284 total reward:-10 epsilon:0.95
# episode:438 steps:300 total reward:-10 epsilon:0.95
# episode:439 steps:259 total reward:-10 epsilon:0.95
# episode:440 steps:272 total reward:-10 epsilon:0.95
# episode:441 steps:270 total reward:-10 epsilon:0.95
# episode:442 steps:275 total reward:-10 epsilon:0.95
# episode:443 steps:319 total reward:-10 epsilon:0.95
# episode:444 steps:277 total reward:-10 epsilon:0.95
# episode:445 steps:272 total reward:-10 epsilon:0.95
# episode:446 steps:244 total reward:-10 epsilon:0.95
# episode:447 steps:244 total reward:-10 epsilon:0.95
# episode:448 steps:262 total reward:-10 epsilon:0.95
# episode:449 steps:289 total reward:-10 epsilon:0.95
# episode:450 steps:296 total reward:-10 epsilon:0.95
# episode:451 steps:325 total reward:-10 epsilon:0.95
# episode:452 steps:279 total reward:-10 epsilon:0.95
# episode:453 steps:259 total reward:-10 epsilon:0.95
# episode:454 steps:272 total reward:-10 epsilon:0.95
# episode:455 steps:264 total reward:-10 epsilon:0.95
# episode:456 steps:264 total reward:-10 epsilon:0.95
# episode:457 steps:270 total reward:-10 epsilon:0.95
# episode:458 steps:289 total reward:-10 epsilon:0.95
# episode:459 steps:274 total reward:-10 epsilon:0.95
# episode:460 steps:272 total reward:-10 epsilon:0.95
# episode:461 steps:277 total reward:-10 epsilon:0.95
# episode:462 steps:281 total reward:-10 epsilon:0.95
# episode:463 steps:269 total reward:-10 epsilon:0.95
# episode:464 steps:338 total reward:-10 epsilon:0.95
# episode:465 steps:286 total reward:-10 epsilon:0.95
# episode:466 steps:265 total reward:-10 epsilon:0.95
# episode:467 steps:263 total reward:-10 epsilon:0.95
# episode:468 steps:240 total reward:-10 epsilon:0.95
# episode:469 steps:255 total reward:-10 epsilon:0.95
# episode:470 steps:303 total reward:-10 epsilon:0.95
# episode:471 steps:338 total reward:-10 epsilon:0.95
# episode:472 steps:401 total reward:-10 epsilon:0.95
# episode:473 steps:443 total reward:-10 epsilon:0.95
# episode:474 steps:351 total reward:-10 epsilon:0.95
# episode:475 steps:368 total reward:-10 epsilon:0.95
# episode:476 steps:423 total reward:-10 epsilon:0.95
# episode:477 steps:500 total reward:0 epsilon:0.95
# episode:478 steps:383 total reward:-10 epsilon:0.95
# episode:479 steps:500 total reward:0 epsilon:0.95
# episode:480 steps:500 total reward:0 epsilon:0.95
# episode:481 steps:500 total reward:0 epsilon:0.95
# episode:482 steps:500 total reward:0 epsilon:0.95
# episode:483 steps:500 total reward:0 epsilon:0.95
# episode:484 steps:500 total reward:0 epsilon:0.95
# episode:485 steps:500 total reward:0 epsilon:0.95
# episode:486 steps:500 total reward:0 epsilon:0.95
# episode:487 steps:500 total reward:0 epsilon:0.95
# episode:488 steps:500 total reward:0 epsilon:0.95
# episode:489 steps:500 total reward:0 epsilon:0.95
# episode:490 steps:500 total reward:0 epsilon:0.95
# episode:491 steps:500 total reward:0 epsilon:0.95
# episode:492 steps:500 total reward:0 epsilon:0.95
# episode:493 steps:500 total reward:0 epsilon:0.95
# episode:494 steps:242 total reward:-10 epsilon:0.95
# episode:495 steps:159 total reward:-10 epsilon:0.95
# episode:496 steps:500 total reward:0 epsilon:0.95
# episode:497 steps:500 total reward:0 epsilon:0.95
# episode:498 steps:500 total reward:0 epsilon:0.95
# episode:499 steps:220 total reward:-10 epsilon:0.95
# episode:500 steps:388 total reward:-10 epsilon:0.95
# episode:501 steps:500 total reward:0 epsilon:0.95
# episode:502 steps:500 total reward:0 epsilon:0.95
# episode:503 steps:500 total reward:0 epsilon:0.95
# episode:504 steps:422 total reward:-10 epsilon:0.95
# episode:505 steps:247 total reward:-10 epsilon:0.95
# episode:506 steps:180 total reward:-10 epsilon:0.95
# episode:507 steps:336 total reward:-10 epsilon:0.95
# episode:508 steps:345 total reward:-10 epsilon:0.95
# episode:509 steps:383 total reward:-10 epsilon:0.95
# episode:510 steps:327 total reward:-10 epsilon:0.95
# episode:511 steps:500 total reward:0 epsilon:0.95
# episode:512 steps:391 total reward:-10 epsilon:0.95
# episode:513 steps:150 total reward:-10 epsilon:0.95
# episode:514 steps:263 total reward:-10 epsilon:0.95
# episode:515 steps:337 total reward:-10 epsilon:0.95
# episode:516 steps:328 total reward:-10 epsilon:0.95
# episode:517 steps:344 total reward:-10 epsilon:0.95
# episode:518 steps:248 total reward:-10 epsilon:0.95
# episode:519 steps:481 total reward:-10 epsilon:0.95
# episode:520 steps:398 total reward:-10 epsilon:0.95
# episode:521 steps:500 total reward:0 epsilon:0.95
# episode:522 steps:500 total reward:0 epsilon:0.95
# episode:523 steps:367 total reward:-10 epsilon:0.95
# episode:524 steps:500 total reward:0 epsilon:0.95
# episode:525 steps:500 total reward:0 epsilon:0.95
# episode:526 steps:500 total reward:0 epsilon:0.95
# episode:527 steps:500 total reward:0 epsilon:0.95
# episode:528 steps:500 total reward:0 epsilon:0.95
# episode:529 steps:500 total reward:0 epsilon:0.95
# episode:530 steps:500 total reward:0 epsilon:0.95
# episode:531 steps:500 total reward:0 epsilon:0.95
# episode:532 steps:500 total reward:0 epsilon:0.95
# episode:533 steps:500 total reward:0 epsilon:0.95
# episode:534 steps:500 total reward:0 epsilon:0.95
# episode:535 steps:500 total reward:0 epsilon:0.95
# episode:536 steps:500 total reward:0 epsilon:0.95
# episode:537 steps:500 total reward:0 epsilon:0.95
# episode:538 steps:500 total reward:0 epsilon:0.95
# episode:539 steps:500 total reward:0 epsilon:0.95
# episode:540 steps:500 total reward:0 epsilon:0.95
# episode:541 steps:500 total reward:0 epsilon:0.95
# episode:542 steps:500 total reward:0 epsilon:0.95
# episode:543 steps:207 total reward:-10 epsilon:0.95
# episode:544 steps:500 total reward:0 epsilon:0.95
# episode:545 steps:489 total reward:-10 epsilon:0.95
# episode:546 steps:398 total reward:-10 epsilon:0.95
# episode:547 steps:474 total reward:-10 epsilon:0.95
# episode:548 steps:357 total reward:-10 epsilon:0.95
# episode:549 steps:360 total reward:-10 epsilon:0.95
# episode:550 steps:345 total reward:-10 epsilon:0.95
# episode:551 steps:346 total reward:-10 epsilon:0.95
# episode:552 steps:351 total reward:-10 epsilon:0.95
# episode:553 steps:286 total reward:-10 epsilon:0.95
# episode:554 steps:309 total reward:-10 epsilon:0.95
# episode:555 steps:208 total reward:-10 epsilon:0.95
# episode:556 steps:354 total reward:-10 epsilon:0.95
# episode:557 steps:494 total reward:-10 epsilon:0.95
# episode:558 steps:413 total reward:-10 epsilon:0.95
# episode:559 steps:500 total reward:0 epsilon:0.95
# episode:560 steps:500 total reward:0 epsilon:0.95
# episode:561 steps:500 total reward:0 epsilon:0.95
# episode:562 steps:500 total reward:0 epsilon:0.95
# episode:563 steps:500 total reward:0 epsilon:0.95
# episode:564 steps:500 total reward:0 epsilon:0.95
# episode:565 steps:500 total reward:0 epsilon:0.95
# episode:566 steps:500 total reward:0 epsilon:0.95
# episode:567 steps:500 total reward:0 epsilon:0.95
# episode:568 steps:500 total reward:0 epsilon:0.95
# episode:569 steps:500 total reward:0 epsilon:0.95
# episode:570 steps:500 total reward:0 epsilon:0.95
# episode:571 steps:500 total reward:0 epsilon:0.95
# episode:572 steps:500 total reward:0 epsilon:0.95
# episode:573 steps:500 total reward:0 epsilon:0.95
# episode:574 steps:500 total reward:0 epsilon:0.95
# episode:575 steps:500 total reward:0 epsilon:0.95
# episode:576 steps:500 total reward:0 epsilon:0.95
# episode:577 steps:500 total reward:0 epsilon:0.95
# episode:578 steps:500 total reward:0 epsilon:0.95
# episode:579 steps:500 total reward:0 epsilon:0.95
# episode:580 steps:500 total reward:0 epsilon:0.95
# episode:581 steps:500 total reward:0 epsilon:0.95
# episode:582 steps:500 total reward:0 epsilon:0.95
# episode:583 steps:500 total reward:0 epsilon:0.95
# episode:584 steps:500 total reward:0 epsilon:0.95
# episode:585 steps:144 total reward:-10 epsilon:0.95
# episode:586 steps:161 total reward:-10 epsilon:0.95
# episode:587 steps:500 total reward:0 epsilon:0.95
# episode:588 steps:500 total reward:0 epsilon:0.95
# episode:589 steps:500 total reward:0 epsilon:0.95
# episode:590 steps:500 total reward:0 epsilon:0.95
# episode:591 steps:500 total reward:0 epsilon:0.95
# episode:592 steps:500 total reward:0 epsilon:0.95
# episode:593 steps:500 total reward:0 epsilon:0.95
# episode:594 steps:312 total reward:-10 epsilon:0.95
# episode:595 steps:500 total reward:0 epsilon:0.95
# episode:596 steps:500 total reward:0 epsilon:0.95
# episode:597 steps:500 total reward:0 epsilon:0.95
# episode:598 steps:500 total reward:0 epsilon:0.95
# episode:599 steps:500 total reward:0 epsilon:0.95
# episode:600 steps:500 total reward:0 epsilon:0.95
# episode:601 steps:500 total reward:0 epsilon:0.95
# episode:602 steps:500 total reward:0 epsilon:0.95
# episode:603 steps:500 total reward:0 epsilon:0.95
# episode:604 steps:500 total reward:0 epsilon:0.95
# episode:605 steps:500 total reward:0 epsilon:0.95
# episode:606 steps:500 total reward:0 epsilon:0.95
# episode:607 steps:500 total reward:0 epsilon:0.95
# episode:608 steps:500 total reward:0 epsilon:0.95
# episode:609 steps:500 total reward:0 epsilon:0.95
# episode:610 steps:500 total reward:0 epsilon:0.95
# episode:611 steps:500 total reward:0 epsilon:0.95
# episode:612 steps:500 total reward:0 epsilon:0.95
# episode:613 steps:500 total reward:0 epsilon:0.95
# episode:614 steps:500 total reward:0 epsilon:0.95
# episode:615 steps:500 total reward:0 epsilon:0.95
# episode:616 steps:500 total reward:0 epsilon:0.95
# episode:617 steps:500 total reward:0 epsilon:0.95
# episode:618 steps:500 total reward:0 epsilon:0.95
# episode:619 steps:500 total reward:0 epsilon:0.95
# episode:620 steps:500 total reward:0 epsilon:0.95
# episode:621 steps:500 total reward:0 epsilon:0.95
# episode:622 steps:500 total reward:0 epsilon:0.95
# episode:623 steps:500 total reward:0 epsilon:0.95
# episode:624 steps:500 total reward:0 epsilon:0.95
# episode:625 steps:500 total reward:0 epsilon:0.95
# episode:626 steps:500 total reward:0 epsilon:0.95
# episode:627 steps:500 total reward:0 epsilon:0.95
# episode:628 steps:500 total reward:0 epsilon:0.95
# episode:629 steps:500 total reward:0 epsilon:0.95
# episode:630 steps:399 total reward:-10 epsilon:0.95
# episode:631 steps:500 total reward:0 epsilon:0.95
# episode:632 steps:500 total reward:0 epsilon:0.95
# episode:633 steps:500 total reward:0 epsilon:0.95
# episode:634 steps:500 total reward:0 epsilon:0.95
# episode:635 steps:500 total reward:0 epsilon:0.95
# episode:636 steps:405 total reward:-10 epsilon:0.95
# episode:637 steps:11 total reward:-10 epsilon:0.95
# episode:638 steps:172 total reward:-10 epsilon:0.95
# episode:639 steps:8 total reward:-10 epsilon:0.95
# episode:640 steps:159 total reward:-10 epsilon:0.95
# episode:641 steps:27 total reward:-10 epsilon:0.95
# episode:642 steps:179 total reward:-10 epsilon:0.95
# episode:643 steps:84 total reward:-10 epsilon:0.95
# episode:644 steps:203 total reward:-10 epsilon:0.95
# episode:645 steps:219 total reward:-10 epsilon:0.95
# episode:646 steps:226 total reward:-10 epsilon:0.95
# episode:647 steps:193 total reward:-10 epsilon:0.95
# episode:648 steps:232 total reward:-10 epsilon:0.95
# episode:649 steps:238 total reward:-10 epsilon:0.95
# episode:650 steps:206 total reward:-10 epsilon:0.95
# episode:651 steps:230 total reward:-10 epsilon:0.95
# episode:652 steps:242 total reward:-10 epsilon:0.95
# episode:653 steps:239 total reward:-10 epsilon:0.95
# episode:654 steps:252 total reward:-10 epsilon:0.95
# episode:655 steps:216 total reward:-10 epsilon:0.95
# episode:656 steps:237 total reward:-10 epsilon:0.95
# episode:657 steps:223 total reward:-10 epsilon:0.95
# episode:658 steps:236 total reward:-10 epsilon:0.95
# episode:659 steps:201 total reward:-10 epsilon:0.95
# episode:660 steps:174 total reward:-10 epsilon:0.95
# episode:661 steps:421 total reward:-10 epsilon:0.95
# episode:662 steps:189 total reward:-10 epsilon:0.95
# episode:663 steps:477 total reward:-10 epsilon:0.95
# episode:664 steps:42 total reward:-10 epsilon:0.95
# episode:665 steps:48 total reward:-10 epsilon:0.95
# episode:666 steps:340 total reward:-10 epsilon:0.95
# episode:667 steps:33 total reward:-10 epsilon:0.95
# episode:668 steps:500 total reward:0 epsilon:0.95
# episode:669 steps:200 total reward:-10 epsilon:0.95
# episode:670 steps:43 total reward:-10 epsilon:0.95
# episode:671 steps:49 total reward:-10 epsilon:0.95
# episode:672 steps:500 total reward:0 epsilon:0.95
# episode:673 steps:44 total reward:-10 epsilon:0.95
# episode:674 steps:493 total reward:-10 epsilon:0.95
# episode:675 steps:56 total reward:-10 epsilon:0.95
# episode:676 steps:63 total reward:-10 epsilon:0.95
# episode:677 steps:414 total reward:-10 epsilon:0.95
# episode:678 steps:500 total reward:0 epsilon:0.95
# episode:679 steps:77 total reward:-10 epsilon:0.95
# episode:680 steps:79 total reward:-10 epsilon:0.95
# episode:681 steps:72 total reward:-10 epsilon:0.95
# episode:682 steps:68 total reward:-10 epsilon:0.95
# episode:683 steps:72 total reward:-10 epsilon:0.95
# episode:684 steps:84 total reward:-10 epsilon:0.95
# episode:685 steps:112 total reward:-10 epsilon:0.95
# episode:686 steps:85 total reward:-10 epsilon:0.95
# episode:687 steps:500 total reward:0 epsilon:0.95
# episode:688 steps:500 total reward:0 epsilon:0.95
# episode:689 steps:73 total reward:-10 epsilon:0.95
# episode:690 steps:66 total reward:-10 epsilon:0.95
# episode:691 steps:69 total reward:-10 epsilon:0.95
# episode:692 steps:85 total reward:-10 epsilon:0.95
# episode:693 steps:500 total reward:0 epsilon:0.95
# episode:694 steps:96 total reward:-10 epsilon:0.95
# episode:695 steps:97 total reward:-10 epsilon:0.95
# episode:696 steps:101 total reward:-10 epsilon:0.95
# episode:697 steps:103 total reward:-10 epsilon:0.95
# episode:698 steps:89 total reward:-10 epsilon:0.95
# episode:699 steps:88 total reward:-10 epsilon:0.95
# episode:700 steps:86 total reward:-10 epsilon:0.95
# episode:701 steps:95 total reward:-10 epsilon:0.95
# episode:702 steps:114 total reward:-10 epsilon:0.95
# episode:703 steps:119 total reward:-10 epsilon:0.95
# episode:704 steps:100 total reward:-10 epsilon:0.95
# episode:705 steps:96 total reward:-10 epsilon:0.95
# episode:706 steps:83 total reward:-10 epsilon:0.95
# episode:707 steps:85 total reward:-10 epsilon:0.95
# episode:708 steps:82 total reward:-10 epsilon:0.95
# episode:709 steps:111 total reward:-10 epsilon:0.95
# episode:710 steps:107 total reward:-10 epsilon:0.95
# episode:711 steps:500 total reward:0 epsilon:0.95
# episode:712 steps:500 total reward:0 epsilon:0.95
# episode:713 steps:130 total reward:-10 epsilon:0.95
# episode:714 steps:500 total reward:0 epsilon:0.95
# episode:715 steps:279 total reward:-10 epsilon:0.95
# episode:716 steps:500 total reward:0 epsilon:0.95
# episode:717 steps:500 total reward:0 epsilon:0.95
# episode:718 steps:87 total reward:-10 epsilon:0.95
# episode:719 steps:500 total reward:0 epsilon:0.95
# episode:720 steps:183 total reward:-10 epsilon:0.95
# episode:721 steps:116 total reward:-10 epsilon:0.95
# episode:722 steps:99 total reward:-10 epsilon:0.95
# episode:723 steps:168 total reward:-10 epsilon:0.95
# episode:724 steps:11 total reward:-10 epsilon:0.95
# episode:725 steps:17 total reward:-10 epsilon:0.95
# episode:726 steps:126 total reward:-10 epsilon:0.95
# episode:727 steps:16 total reward:-10 epsilon:0.95
# episode:728 steps:11 total reward:-10 epsilon:0.95
# episode:729 steps:10 total reward:-10 epsilon:0.95
# episode:730 steps:11 total reward:-10 epsilon:0.95
# episode:731 steps:9 total reward:-10 epsilon:0.95
# episode:732 steps:147 total reward:-10 epsilon:0.95
# episode:733 steps:10 total reward:-10 epsilon:0.95
# episode:734 steps:9 total reward:-10 epsilon:0.95
# episode:735 steps:10 total reward:-10 epsilon:0.95
# episode:736 steps:9 total reward:-10 epsilon:0.95
# episode:737 steps:10 total reward:-10 epsilon:0.95
# episode:738 steps:10 total reward:-10 epsilon:0.95
# episode:739 steps:17 total reward:-10 epsilon:0.95
# episode:740 steps:8 total reward:-10 epsilon:0.95
# episode:741 steps:10 total reward:-10 epsilon:0.95
# episode:742 steps:9 total reward:-10 epsilon:0.95
# episode:743 steps:16 total reward:-10 epsilon:0.95
# episode:744 steps:10 total reward:-10 epsilon:0.95
# episode:745 steps:14 total reward:-10 epsilon:0.95
# episode:746 steps:9 total reward:-10 epsilon:0.95
# episode:747 steps:10 total reward:-10 epsilon:0.95
# episode:748 steps:15 total reward:-10 epsilon:0.95
# episode:749 steps:8 total reward:-10 epsilon:0.95
# episode:750 steps:12 total reward:-10 epsilon:0.95
# episode:751 steps:16 total reward:-10 epsilon:0.95
# episode:752 steps:12 total reward:-10 epsilon:0.95
# episode:753 steps:10 total reward:-10 epsilon:0.95
# episode:754 steps:9 total reward:-10 epsilon:0.95
# episode:755 steps:9 total reward:-10 epsilon:0.95
# episode:756 steps:8 total reward:-10 epsilon:0.95
# episode:757 steps:12 total reward:-10 epsilon:0.95
# episode:758 steps:9 total reward:-10 epsilon:0.95
# episode:759 steps:15 total reward:-10 epsilon:0.95
# episode:760 steps:9 total reward:-10 epsilon:0.95
# episode:761 steps:20 total reward:-10 epsilon:0.95
# episode:762 steps:9 total reward:-10 epsilon:0.95
# episode:763 steps:8 total reward:-10 epsilon:0.95
# episode:764 steps:12 total reward:-10 epsilon:0.95
# episode:765 steps:9 total reward:-10 epsilon:0.95
# episode:766 steps:9 total reward:-10 epsilon:0.95
# episode:767 steps:9 total reward:-10 epsilon:0.95
# episode:768 steps:9 total reward:-10 epsilon:0.95
# episode:769 steps:9 total reward:-10 epsilon:0.95
# episode:770 steps:9 total reward:-10 epsilon:0.95
# episode:771 steps:10 total reward:-10 epsilon:0.95
# episode:772 steps:9 total reward:-10 epsilon:0.95
# episode:773 steps:8 total reward:-10 epsilon:0.95
# episode:774 steps:8 total reward:-10 epsilon:0.95
# episode:775 steps:9 total reward:-10 epsilon:0.95
# episode:776 steps:8 total reward:-10 epsilon:0.95
# episode:777 steps:9 total reward:-10 epsilon:0.95
# episode:778 steps:8 total reward:-10 epsilon:0.95
# episode:779 steps:8 total reward:-10 epsilon:0.95
# episode:780 steps:9 total reward:-10 epsilon:0.95
# episode:781 steps:8 total reward:-10 epsilon:0.95
# episode:782 steps:9 total reward:-10 epsilon:0.95
# episode:783 steps:8 total reward:-10 epsilon:0.95
# episode:784 steps:9 total reward:-10 epsilon:0.95
# episode:785 steps:10 total reward:-10 epsilon:0.95
# episode:786 steps:8 total reward:-10 epsilon:0.95
# episode:787 steps:10 total reward:-10 epsilon:0.95
# episode:788 steps:9 total reward:-10 epsilon:0.95
# episode:789 steps:16 total reward:-10 epsilon:0.95
# episode:790 steps:9 total reward:-10 epsilon:0.95
# episode:791 steps:7 total reward:-10 epsilon:0.95
# episode:792 steps:8 total reward:-10 epsilon:0.95
# episode:793 steps:24 total reward:-10 epsilon:0.95
# episode:794 steps:10 total reward:-10 epsilon:0.95
# episode:795 steps:12 total reward:-10 epsilon:0.95
# episode:796 steps:18 total reward:-10 epsilon:0.95
# episode:797 steps:26 total reward:-10 epsilon:0.95
# episode:798 steps:89 total reward:-10 epsilon:0.95
# episode:799 steps:500 total reward:0 epsilon:0.95
# episode:800 steps:500 total reward:0 epsilon:0.95
# episode:801 steps:171 total reward:-10 epsilon:0.95
# episode:802 steps:203 total reward:-10 epsilon:0.95
# episode:803 steps:187 total reward:-10 epsilon:0.95
# episode:804 steps:203 total reward:-10 epsilon:0.95
# episode:805 steps:264 total reward:-10 epsilon:0.95
# episode:806 steps:500 total reward:0 epsilon:0.95
# episode:807 steps:500 total reward:0 epsilon:0.95
# episode:808 steps:500 total reward:0 epsilon:0.95
# episode:809 steps:258 total reward:-10 epsilon:0.95
# episode:810 steps:500 total reward:0 epsilon:0.95
# episode:811 steps:500 total reward:0 epsilon:0.95
# episode:812 steps:500 total reward:0 epsilon:0.95
# episode:813 steps:500 total reward:0 epsilon:0.95
# episode:814 steps:500 total reward:0 epsilon:0.95
# episode:815 steps:500 total reward:0 epsilon:0.95
# episode:816 steps:500 total reward:0 epsilon:0.95
# episode:817 steps:500 total reward:0 epsilon:0.95
# episode:818 steps:500 total reward:0 epsilon:0.95
# episode:819 steps:500 total reward:0 epsilon:0.95
# episode:820 steps:500 total reward:0 epsilon:0.95
# episode:821 steps:500 total reward:0 epsilon:0.95
# episode:822 steps:500 total reward:0 epsilon:0.95
# episode:823 steps:500 total reward:0 epsilon:0.95
# episode:824 steps:500 total reward:0 epsilon:0.95
# episode:825 steps:500 total reward:0 epsilon:0.95
# episode:826 steps:78 total reward:-10 epsilon:0.95
# episode:827 steps:35 total reward:-10 epsilon:0.95
# episode:828 steps:33 total reward:-10 epsilon:0.95
# episode:829 steps:41 total reward:-10 epsilon:0.95
# episode:830 steps:74 total reward:-10 epsilon:0.95
# episode:831 steps:56 total reward:-10 epsilon:0.95
# episode:832 steps:126 total reward:-10 epsilon:0.95
# episode:833 steps:101 total reward:-10 epsilon:0.95
# episode:834 steps:126 total reward:-10 epsilon:0.95
# episode:835 steps:500 total reward:0 epsilon:0.95
# episode:836 steps:500 total reward:0 epsilon:0.95
# episode:837 steps:102 total reward:-10 epsilon:0.95
# episode:838 steps:256 total reward:-10 epsilon:0.95
# episode:839 steps:500 total reward:0 epsilon:0.95
# episode:840 steps:500 total reward:0 epsilon:0.95
# episode:841 steps:500 total reward:0 epsilon:0.95
# episode:842 steps:500 total reward:0 epsilon:0.95
# episode:843 steps:500 total reward:0 epsilon:0.95
# episode:844 steps:500 total reward:0 epsilon:0.95
# episode:845 steps:500 total reward:0 epsilon:0.95
# episode:846 steps:500 total reward:0 epsilon:0.95
# episode:847 steps:500 total reward:0 epsilon:0.95
# episode:848 steps:500 total reward:0 epsilon:0.95
# episode:849 steps:500 total reward:0 epsilon:0.95
# episode:850 steps:500 total reward:0 epsilon:0.95
# episode:851 steps:468 total reward:-10 epsilon:0.95
# episode:852 steps:500 total reward:0 epsilon:0.95
# episode:853 steps:500 total reward:0 epsilon:0.95
# episode:854 steps:500 total reward:0 epsilon:0.95
# episode:855 steps:500 total reward:0 epsilon:0.95
# episode:856 steps:500 total reward:0 epsilon:0.95
# episode:857 steps:500 total reward:0 epsilon:0.95
# episode:858 steps:500 total reward:0 epsilon:0.95
# episode:859 steps:500 total reward:0 epsilon:0.95
# episode:860 steps:500 total reward:0 epsilon:0.95
# episode:861 steps:500 total reward:0 epsilon:0.95
# episode:862 steps:500 total reward:0 epsilon:0.95
# episode:863 steps:500 total reward:0 epsilon:0.95
# episode:864 steps:500 total reward:0 epsilon:0.95
# episode:865 steps:500 total reward:0 epsilon:0.95
# episode:866 steps:500 total reward:0 epsilon:0.95
# episode:867 steps:500 total reward:0 epsilon:0.95
# episode:868 steps:500 total reward:0 epsilon:0.95
# episode:869 steps:500 total reward:0 epsilon:0.95
# episode:870 steps:500 total reward:0 epsilon:0.95
# episode:871 steps:500 total reward:0 epsilon:0.95
# episode:872 steps:500 total reward:0 epsilon:0.95
# episode:873 steps:500 total reward:0 epsilon:0.95
# episode:874 steps:500 total reward:0 epsilon:0.95
# episode:875 steps:500 total reward:0 epsilon:0.95
# episode:876 steps:500 total reward:0 epsilon:0.95
# episode:877 steps:500 total reward:0 epsilon:0.95
# episode:878 steps:500 total reward:0 epsilon:0.95
# episode:879 steps:500 total reward:0 epsilon:0.95
# episode:880 steps:500 total reward:0 epsilon:0.95
# episode:881 steps:500 total reward:0 epsilon:0.95
# episode:882 steps:500 total reward:0 epsilon:0.95
# episode:883 steps:500 total reward:0 epsilon:0.95
# episode:884 steps:500 total reward:0 epsilon:0.95
# episode:885 steps:500 total reward:0 epsilon:0.95
# episode:886 steps:500 total reward:0 epsilon:0.95
# episode:887 steps:500 total reward:0 epsilon:0.95
# episode:888 steps:500 total reward:0 epsilon:0.95
# episode:889 steps:500 total reward:0 epsilon:0.95
# episode:890 steps:500 total reward:0 epsilon:0.95
# episode:891 steps:500 total reward:0 epsilon:0.95
# episode:892 steps:500 total reward:0 epsilon:0.95
# episode:893 steps:500 total reward:0 epsilon:0.95
# episode:894 steps:500 total reward:0 epsilon:0.95
# episode:895 steps:500 total reward:0 epsilon:0.95
# episode:896 steps:500 total reward:0 epsilon:0.95
# episode:897 steps:500 total reward:0 epsilon:0.95
# episode:898 steps:500 total reward:0 epsilon:0.95
# episode:899 steps:500 total reward:0 epsilon:0.95
# episode:900 steps:500 total reward:0 epsilon:0.95
# episode:901 steps:500 total reward:0 epsilon:0.95
# episode:902 steps:500 total reward:0 epsilon:0.95
# episode:903 steps:500 total reward:0 epsilon:0.95
# episode:904 steps:500 total reward:0 epsilon:0.95
# episode:905 steps:500 total reward:0 epsilon:0.95
# episode:906 steps:500 total reward:0 epsilon:0.95
# episode:907 steps:500 total reward:0 epsilon:0.95
# episode:908 steps:500 total reward:0 epsilon:0.95
# episode:909 steps:500 total reward:0 epsilon:0.95
# episode:910 steps:500 total reward:0 epsilon:0.95
# episode:911 steps:500 total reward:0 epsilon:0.95
# episode:912 steps:500 total reward:0 epsilon:0.95
# episode:913 steps:500 total reward:0 epsilon:0.95
# episode:914 steps:500 total reward:0 epsilon:0.95
# episode:915 steps:500 total reward:0 epsilon:0.95
# episode:916 steps:500 total reward:0 epsilon:0.95
# episode:917 steps:500 total reward:0 epsilon:0.95
# episode:918 steps:500 total reward:0 epsilon:0.95
# episode:919 steps:500 total reward:0 epsilon:0.95
# episode:920 steps:500 total reward:0 epsilon:0.95
# episode:921 steps:500 total reward:0 epsilon:0.95
# episode:922 steps:500 total reward:0 epsilon:0.95
# episode:923 steps:500 total reward:0 epsilon:0.95
# episode:924 steps:500 total reward:0 epsilon:0.95
# episode:925 steps:500 total reward:0 epsilon:0.95
# episode:926 steps:500 total reward:0 epsilon:0.95
# episode:927 steps:500 total reward:0 epsilon:0.95
# episode:928 steps:500 total reward:0 epsilon:0.95
# ...
# episode:1691 steps:181 total reward:-10 epsilon:0.95
# episode:1692 steps:160 total reward:-10 epsilon:0.95
# episode:1693 steps:251 total reward:-10 epsilon:0.95
# episode:1694 steps:160 total reward:-10 epsilon:0.95
# episode:1695 steps:151 total reward:-10 epsilon:0.95
# episode:1696 steps:178 total reward:-10 epsilon:0.95
# episode:1697 steps:285 total reward:-10 epsilon:0.95
# episode:1698 steps:169 total reward:-10 epsilon:0.95
# episode:1699 steps:500 total reward:0 epsilon:0.95
# episode:1700 steps:249 total reward:-10 epsilon:0.95
# episode:1701 steps:201 total reward:-10 epsilon:0.95
# episode:1702 steps:402 total reward:-10 epsilon:0.95
# episode:1703 steps:283 total reward:-10 epsilon:0.95
# episode:1704 steps:194 total reward:-10 epsilon:0.95
# episode:1705 steps:139 total reward:-10 epsilon:0.95
# episode:1706 steps:131 total reward:-10 epsilon:0.95
# episode:1707 steps:228 total reward:-10 epsilon:0.95
# episode:1708 steps:196 total reward:-10 epsilon:0.95
# episode:1709 steps:163 total reward:-10 epsilon:0.95
# episode:1710 steps:221 total reward:-10 epsilon:0.95
# episode:1711 steps:210 total reward:-10 epsilon:0.95
# episode:1712 steps:337 total reward:-10 epsilon:0.95
# episode:1713 steps:150 total reward:-10 epsilon:0.95
# episode:1714 steps:287 total reward:-10 epsilon:0.95
# episode:1715 steps:155 total reward:-10 epsilon:0.95
# episode:1716 steps:180 total reward:-10 epsilon:0.95
# episode:1717 steps:180 total reward:-10 epsilon:0.95
# episode:1718 steps:167 total reward:-10 epsilon:0.95
# episode:1719 steps:155 total reward:-10 epsilon:0.95
# episode:1720 steps:500 total reward:0 epsilon:0.95
# episode:1721 steps:500 total reward:0 epsilon:0.95
# episode:1722 steps:500 total reward:0 epsilon:0.95
# episode:1723 steps:500 total reward:0 epsilon:0.95
# episode:1724 steps:500 total reward:0 epsilon:0.95
# episode:1725 steps:500 total reward:0 epsilon:0.95
# episode:1726 steps:500 total reward:0 epsilon:0.95
# episode:1727 steps:500 total reward:0 epsilon:0.95
# episode:1728 steps:407 total reward:-10 epsilon:0.95
# episode:1729 steps:451 total reward:-10 epsilon:0.95
# episode:1730 steps:444 total reward:-10 epsilon:0.95
# episode:1731 steps:432 total reward:-10 epsilon:0.95
# episode:1732 steps:395 total reward:-10 epsilon:0.95
# episode:1733 steps:437 total reward:-10 epsilon:0.95
# episode:1734 steps:490 total reward:-10 epsilon:0.95
# episode:1735 steps:500 total reward:0 epsilon:0.95
# episode:1736 steps:500 total reward:0 epsilon:0.95
# episode:1737 steps:500 total reward:0 epsilon:0.95
# episode:1738 steps:500 total reward:0 epsilon:0.95
# episode:1739 steps:454 total reward:-10 epsilon:0.95
# episode:1740 steps:368 total reward:-10 epsilon:0.95
# episode:1741 steps:357 total reward:-10 epsilon:0.95
# episode:1742 steps:440 total reward:-10 epsilon:0.95
# episode:1743 steps:500 total reward:0 epsilon:0.95
# episode:1744 steps:500 total reward:0 epsilon:0.95
# episode:1745 steps:500 total reward:0 epsilon:0.95
# episode:1746 steps:500 total reward:0 epsilon:0.95
# episode:1747 steps:500 total reward:0 epsilon:0.95
# episode:1748 steps:500 total reward:0 epsilon:0.95
# episode:1749 steps:500 total reward:0 epsilon:0.95
# episode:1750 steps:500 total reward:0 epsilon:0.95
# episode:1751 steps:500 total reward:0 epsilon:0.95
# episode:1752 steps:500 total reward:0 epsilon:0.95
# episode:1753 steps:500 total reward:0 epsilon:0.95
# episode:1754 steps:500 total reward:0 epsilon:0.95
# episode:1755 steps:500 total reward:0 epsilon:0.95
# episode:1756 steps:500 total reward:0 epsilon:0.95
# episode:1757 steps:500 total reward:0 epsilon:0.95
# episode:1758 steps:500 total reward:0 epsilon:0.95
# episode:1759 steps:500 total reward:0 epsilon:0.95
# episode:1760 steps:500 total reward:0 epsilon:0.95
# episode:1761 steps:500 total reward:0 epsilon:0.95
# episode:1762 steps:500 total reward:0 epsilon:0.95
# episode:1763 steps:500 total reward:0 epsilon:0.95
# episode:1764 steps:500 total reward:0 epsilon:0.95
# episode:1765 steps:500 total reward:0 epsilon:0.95
# episode:1766 steps:500 total reward:0 epsilon:0.95
# episode:1767 steps:500 total reward:0 epsilon:0.95
# episode:1768 steps:500 total reward:0 epsilon:0.95
# episode:1769 steps:500 total reward:0 epsilon:0.95
# episode:1770 steps:500 total reward:0 epsilon:0.95
# episode:1771 steps:500 total reward:0 epsilon:0.95
# episode:1772 steps:500 total reward:0 epsilon:0.95
# episode:1773 steps:500 total reward:0 epsilon:0.95
# episode:1774 steps:500 total reward:0 epsilon:0.95
# episode:1775 steps:500 total reward:0 epsilon:0.95
# episode:1776 steps:500 total reward:0 epsilon:0.95
# episode:1777 steps:500 total reward:0 epsilon:0.95
# episode:1778 steps:500 total reward:0 epsilon:0.95
# episode:1779 steps:500 total reward:0 epsilon:0.95
# episode:1780 steps:500 total reward:0 epsilon:0.95
# episode:1781 steps:500 total reward:0 epsilon:0.95
# episode:1782 steps:500 total reward:0 epsilon:0.95
# episode:1783 steps:309 total reward:-10 epsilon:0.95
# episode:1784 steps:161 total reward:-10 epsilon:0.95
# episode:1785 steps:500 total reward:0 epsilon:0.95
# episode:1786 steps:500 total reward:0 epsilon:0.95
# episode:1787 steps:396 total reward:-10 epsilon:0.95
# episode:1788 steps:403 total reward:-10 epsilon:0.95
# episode:1789 steps:27 total reward:-10 epsilon:0.95
# episode:1790 steps:81 total reward:-10 epsilon:0.95
# episode:1791 steps:52 total reward:-10 epsilon:0.95
# episode:1792 steps:70 total reward:-10 epsilon:0.95
# episode:1793 steps:60 total reward:-10 epsilon:0.95
# episode:1794 steps:64 total reward:-10 epsilon:0.95
# episode:1795 steps:65 total reward:-10 epsilon:0.95
# episode:1796 steps:500 total reward:0 epsilon:0.95
# episode:1797 steps:500 total reward:0 epsilon:0.95
# episode:1798 steps:500 total reward:0 epsilon:0.95
# episode:1799 steps:500 total reward:0 epsilon:0.95
# episode:1800 steps:500 total reward:0 epsilon:0.95
# episode:1801 steps:500 total reward:0 epsilon:0.95
# episode:1802 steps:500 total reward:0 epsilon:0.95
# episode:1803 steps:500 total reward:0 epsilon:0.95
# episode:1804 steps:500 total reward:0 epsilon:0.95
# episode:1805 steps:500 total reward:0 epsilon:0.95
# episode:1806 steps:500 total reward:0 epsilon:0.95
# episode:1807 steps:500 total reward:0 epsilon:0.95
# episode:1808 steps:500 total reward:0 epsilon:0.95
# episode:1809 steps:500 total reward:0 epsilon:0.95
# episode:1810 steps:500 total reward:0 epsilon:0.95
# episode:1811 steps:500 total reward:0 epsilon:0.95
# episode:1812 steps:500 total reward:0 epsilon:0.95
# episode:1813 steps:500 total reward:0 epsilon:0.95
# episode:1814 steps:500 total reward:0 epsilon:0.95
# episode:1815 steps:500 total reward:0 epsilon:0.95
# episode:1816 steps:388 total reward:-10 epsilon:0.95
# episode:1817 steps:50 total reward:-10 epsilon:0.95
# episode:1818 steps:54 total reward:-10 epsilon:0.95
# episode:1819 steps:53 total reward:-10 epsilon:0.95
# episode:1820 steps:59 total reward:-10 epsilon:0.95
# episode:1821 steps:47 total reward:-10 epsilon:0.95
# episode:1822 steps:56 total reward:-10 epsilon:0.95
# episode:1823 steps:51 total reward:-10 epsilon:0.95
# episode:1824 steps:49 total reward:-10 epsilon:0.95
# episode:1825 steps:62 total reward:-10 epsilon:0.95
# episode:1826 steps:71 total reward:-10 epsilon:0.95
# episode:1827 steps:67 total reward:-10 epsilon:0.95
# episode:1828 steps:67 total reward:-10 epsilon:0.95
# episode:1829 steps:500 total reward:0 epsilon:0.95
# episode:1830 steps:500 total reward:0 epsilon:0.95
# episode:1831 steps:500 total reward:0 epsilon:0.95
# episode:1832 steps:500 total reward:0 epsilon:0.95
# episode:1833 steps:500 total reward:0 epsilon:0.95
# episode:1834 steps:500 total reward:0 epsilon:0.95
# episode:1835 steps:500 total reward:0 epsilon:0.95
# episode:1836 steps:500 total reward:0 epsilon:0.95
# episode:1837 steps:500 total reward:0 epsilon:0.95
# episode:1838 steps:500 total reward:0 epsilon:0.95
# episode:1839 steps:500 total reward:0 epsilon:0.95
# episode:1840 steps:500 total reward:0 epsilon:0.95
# episode:1841 steps:500 total reward:0 epsilon:0.95
# episode:1842 steps:413 total reward:-10 epsilon:0.95
# episode:1843 steps:500 total reward:0 epsilon:0.95
# episode:1844 steps:199 total reward:-10 epsilon:0.95
# episode:1845 steps:169 total reward:-10 epsilon:0.95
# episode:1846 steps:174 total reward:-10 epsilon:0.95
# episode:1847 steps:84 total reward:-10 epsilon:0.95
# episode:1848 steps:83 total reward:-10 epsilon:0.95
# episode:1849 steps:90 total reward:-10 epsilon:0.95
# episode:1850 steps:69 total reward:-10 epsilon:0.95
# episode:1851 steps:59 total reward:-10 epsilon:0.95
# episode:1852 steps:70 total reward:-10 epsilon:0.95
# episode:1853 steps:62 total reward:-10 epsilon:0.95
# episode:1854 steps:80 total reward:-10 epsilon:0.95
# episode:1855 steps:68 total reward:-10 epsilon:0.95
# episode:1856 steps:76 total reward:-10 epsilon:0.95
# episode:1857 steps:78 total reward:-10 epsilon:0.95
# episode:1858 steps:84 total reward:-10 epsilon:0.95
# episode:1859 steps:80 total reward:-10 epsilon:0.95
# episode:1860 steps:82 total reward:-10 epsilon:0.95
# episode:1861 steps:70 total reward:-10 epsilon:0.95
# episode:1862 steps:78 total reward:-10 epsilon:0.95
# episode:1863 steps:78 total reward:-10 epsilon:0.95
# episode:1864 steps:70 total reward:-10 epsilon:0.95
# episode:1865 steps:85 total reward:-10 epsilon:0.95
# episode:1866 steps:82 total reward:-10 epsilon:0.95
# episode:1867 steps:89 total reward:-10 epsilon:0.95
# episode:1868 steps:97 total reward:-10 epsilon:0.95
# episode:1869 steps:102 total reward:-10 epsilon:0.95
# episode:1870 steps:102 total reward:-10 epsilon:0.95
# episode:1871 steps:140 total reward:-10 epsilon:0.95
# episode:1872 steps:146 total reward:-10 epsilon:0.95
# episode:1873 steps:139 total reward:-10 epsilon:0.95
# episode:1874 steps:120 total reward:-10 epsilon:0.95
# episode:1875 steps:127 total reward:-10 epsilon:0.95
# episode:1876 steps:115 total reward:-10 epsilon:0.95
# episode:1877 steps:117 total reward:-10 epsilon:0.95
# episode:1878 steps:114 total reward:-10 epsilon:0.95
# episode:1879 steps:115 total reward:-10 epsilon:0.95
# episode:1880 steps:115 total reward:-10 epsilon:0.95
# episode:1881 steps:109 total reward:-10 epsilon:0.95
# episode:1882 steps:109 total reward:-10 epsilon:0.95
# episode:1883 steps:97 total reward:-10 epsilon:0.95
# episode:1884 steps:17 total reward:-10 epsilon:0.95
# episode:1885 steps:96 total reward:-10 epsilon:0.95
# episode:1886 steps:24 total reward:-10 epsilon:0.95
# episode:1887 steps:93 total reward:-10 epsilon:0.95
# episode:1888 steps:93 total reward:-10 epsilon:0.95
# episode:1889 steps:25 total reward:-10 epsilon:0.95
# episode:1890 steps:99 total reward:-10 epsilon:0.95
# episode:1891 steps:33 total reward:-10 epsilon:0.95
# episode:1892 steps:102 total reward:-10 epsilon:0.95
# episode:1893 steps:29 total reward:-10 epsilon:0.95
# episode:1894 steps:104 total reward:-10 epsilon:0.95
# episode:1895 steps:99 total reward:-10 epsilon:0.95
# episode:1896 steps:107 total reward:-10 epsilon:0.95
# episode:1897 steps:220 total reward:-10 epsilon:0.95
# episode:1898 steps:500 total reward:0 epsilon:0.95
# episode:1899 steps:500 total reward:0 epsilon:0.95
# episode:1900 steps:500 total reward:0 epsilon:0.95
# episode:1901 steps:500 total reward:0 epsilon:0.95
# episode:1902 steps:500 total reward:0 epsilon:0.95
# episode:1903 steps:500 total reward:0 epsilon:0.95
# episode:1904 steps:500 total reward:0 epsilon:0.95
# episode:1905 steps:500 total reward:0 epsilon:0.95
# episode:1906 steps:500 total reward:0 epsilon:0.95
# episode:1907 steps:500 total reward:0 epsilon:0.95
# episode:1908 steps:500 total reward:0 epsilon:0.95
# episode:1909 steps:500 total reward:0 epsilon:0.95
# episode:1910 steps:500 total reward:0 epsilon:0.95
# episode:1911 steps:500 total reward:0 epsilon:0.95
# episode:1912 steps:500 total reward:0 epsilon:0.95
# episode:1913 steps:500 total reward:0 epsilon:0.95
# episode:1914 steps:500 total reward:0 epsilon:0.95
# episode:1915 steps:500 total reward:0 epsilon:0.95
# episode:1916 steps:500 total reward:0 epsilon:0.95
# episode:1917 steps:500 total reward:0 epsilon:0.95
# episode:1918 steps:124 total reward:-10 epsilon:0.95
# episode:1919 steps:23 total reward:-10 epsilon:0.95
# episode:1920 steps:122 total reward:-10 epsilon:0.95
# episode:1921 steps:123 total reward:-10 epsilon:0.95
# episode:1922 steps:135 total reward:-10 epsilon:0.95
# episode:1923 steps:116 total reward:-10 epsilon:0.95
# episode:1924 steps:168 total reward:-10 epsilon:0.95
# episode:1925 steps:215 total reward:-10 epsilon:0.95
# episode:1926 steps:210 total reward:-10 epsilon:0.95
# episode:1927 steps:123 total reward:-10 epsilon:0.95
# episode:1928 steps:107 total reward:-10 epsilon:0.95
# episode:1929 steps:167 total reward:-10 epsilon:0.95
# episode:1930 steps:141 total reward:-10 epsilon:0.95
# episode:1931 steps:500 total reward:0 epsilon:0.95
# episode:1932 steps:500 total reward:0 epsilon:0.95
# episode:1933 steps:259 total reward:-10 epsilon:0.95
# episode:1934 steps:500 total reward:0 epsilon:0.95
# episode:1935 steps:500 total reward:0 epsilon:0.95
# episode:1936 steps:500 total reward:0 epsilon:0.95
# episode:1937 steps:500 total reward:0 epsilon:0.95
# episode:1938 steps:500 total reward:0 epsilon:0.95
# episode:1939 steps:500 total reward:0 epsilon:0.95
# episode:1940 steps:500 total reward:0 epsilon:0.95
# episode:1941 steps:500 total reward:0 epsilon:0.95
# episode:1942 steps:500 total reward:0 epsilon:0.95
# episode:1943 steps:500 total reward:0 epsilon:0.95
# episode:1944 steps:500 total reward:0 epsilon:0.95
# episode:1945 steps:500 total reward:0 epsilon:0.95
# episode:1946 steps:500 total reward:0 epsilon:0.95
# episode:1947 steps:500 total reward:0 epsilon:0.95
# episode:1948 steps:500 total reward:0 epsilon:0.95
# episode:1949 steps:500 total reward:0 epsilon:0.95
# episode:1950 steps:500 total reward:0 epsilon:0.95
# episode:1951 steps:500 total reward:0 epsilon:0.95
# episode:1952 steps:500 total reward:0 epsilon:0.95
# episode:1953 steps:500 total reward:0 epsilon:0.95
# episode:1954 steps:500 total reward:0 epsilon:0.95
# episode:1955 steps:500 total reward:0 epsilon:0.95
# episode:1956 steps:500 total reward:0 epsilon:0.95
# episode:1957 steps:500 total reward:0 epsilon:0.95
# episode:1958 steps:500 total reward:0 epsilon:0.95
# episode:1959 steps:11 total reward:-10 epsilon:0.95
# episode:1960 steps:500 total reward:0 epsilon:0.95
# episode:1961 steps:500 total reward:0 epsilon:0.95
# episode:1962 steps:500 total reward:0 epsilon:0.95
# episode:1963 steps:500 total reward:0 epsilon:0.95
# episode:1964 steps:500 total reward:0 epsilon:0.95
# episode:1965 steps:500 total reward:0 epsilon:0.95
# episode:1966 steps:500 total reward:0 epsilon:0.95
# episode:1967 steps:500 total reward:0 epsilon:0.95
# episode:1968 steps:500 total reward:0 epsilon:0.95
# episode:1969 steps:500 total reward:0 epsilon:0.95
# episode:1970 steps:500 total reward:0 epsilon:0.95
# episode:1971 steps:14 total reward:-10 epsilon:0.95
# episode:1972 steps:500 total reward:0 epsilon:0.95
# episode:1973 steps:500 total reward:0 epsilon:0.95
# episode:1974 steps:500 total reward:0 epsilon:0.95
# episode:1975 steps:500 total reward:0 epsilon:0.95
# episode:1976 steps:500 total reward:0 epsilon:0.95
# episode:1977 steps:500 total reward:0 epsilon:0.95
# episode:1978 steps:500 total reward:0 epsilon:0.95
# episode:1979 steps:500 total reward:0 epsilon:0.95
# episode:1980 steps:500 total reward:0 epsilon:0.95
# episode:1981 steps:500 total reward:0 epsilon:0.95
# episode:1982 steps:500 total reward:0 epsilon:0.95
# episode:1983 steps:500 total reward:0 epsilon:0.95
# episode:1984 steps:500 total reward:0 epsilon:0.95
# episode:1985 steps:500 total reward:0 epsilon:0.95
# episode:1986 steps:500 total reward:0 epsilon:0.95
# episode:1987 steps:500 total reward:0 epsilon:0.95
# episode:1988 steps:500 total reward:0 epsilon:0.95
# episode:1989 steps:193 total reward:-10 epsilon:0.95
# episode:1990 steps:319 total reward:-10 epsilon:0.95
# episode:1991 steps:18 total reward:-10 epsilon:0.95
# episode:1992 steps:198 total reward:-10 epsilon:0.95
# episode:1993 steps:500 total reward:0 epsilon:0.95
# episode:1994 steps:500 total reward:0 epsilon:0.95
# episode:1995 steps:500 total reward:0 epsilon:0.95
# episode:1996 steps:500 total reward:0 epsilon:0.95
# episode:1997 steps:500 total reward:0 epsilon:0.95
# episode:1998 steps:500 total reward:0 epsilon:0.95
# episode:1999 steps:500 total reward:0 epsilon:0.95
# game over

# %%
step_result = pd.concat(step_result)
step_result.columns = ['prioritized_DQN']

# %%
step_result.plot()
plt.xlabel('Episode')
plt.ylabel('Steps')
plt.show()
