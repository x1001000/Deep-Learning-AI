# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import gym

# %% [markdown]
# # 建力Policy Gradient模型

# %%
class Policy_Gradient:
    
    def __init__(
        self, 
        n_actions, 
        n_states, 
        gamma = 0.9, #遠見程度
        epsilon = None,  #保守程度，越大就越容易用Q值大小來採取行動；越小則越容易產生隨機行動
        epsilon_increase = None,
        learning_rate = 0.001, #神經網路的更新率
        #memory_size = 50, #####
        #batch_size = 32, #####
        nueron_num = 10
    ):
    
        self.n_actions = n_actions
        self.n_states = n_states
        self.gamma = gamma
        #self.epsilon_max = epsilon #####
        #self.epsilon_increase = epsilon_increase #####
        #self.epsilon = 0 if epsilon_increase is not None else epsilon #####
        self.lr = learning_rate
        #self.memory_size = memory_size #####
        #self.memory_counter = 0 #####
        #self.batch_size = batch_size ####
        self.nueron_num = nueron_num
        
        ##### initialize memory
        """
        
        """
        self.past_state, self.past_action, self.past_reward = [], [], []
        self.action_one_hot = np.zeros(self.n_actions, dtype=np.int32)

        """

        """
        
        tf.reset_default_graph() ## 重新 build graph 需要跑這行
        self.sess = tf.Session() #宣告session
        #輸入current state
        self.state_input = tf.placeholder(shape = [None, self.n_states], 
                                          name = 'state_input',
                                          dtype = tf.float32)
        """
        輸入real action和神經網路的output act_proba算cross entropy當作更新方向
        以超級瑪莉的遊戲為例 action = [上, 下, 左, 右] 如果實際action為向左則
        action = [0, 0, 1, 0]。
        也可以將這四個動作用0, 1, 2 ,3代表，如此的話只需要用一維來存取動作，也就是輸
        入shape = [None, 1]，那後面再算cross entropy的話就要用tf.nn.sparse_
        softmax_cross_entropy_with_logits，大家也可以試著改寫看看。
        """    
        self.real_action = tf.placeholder(shape = [None, self.n_actions], 
                                          name = 'real_action',
                                          dtype = tf.float32)
        """
        但是有時候產生的動作會帶來好的效果或壞的效果並且程度不一，因此loss不能光用神經網路的
        輸出action_proba和real action的cross entropy代表，因此這邊乘上Vt來校正loss。
        例如某個動作很有幫助那必然會產生很大的action_reward，因此乘上很大的action_reward
        即可加大loss讓此動作之後產生的機率被放大；相反的，某個動作如果產生很好的效果反而會帶
        來負的action_reward使得loss變負的，讓更新方向相反使得之後輸出此動作的機會減少。
        """
        self.Vt = tf.placeholder(shape= [None, ], 
                                            name="Vt",
                                            dtype = tf.float32)
        #搭建神經網路
        with tf.variable_scope('Actor'):
            self.act_proba = self.build_network(self.nueron_num, Trainable = True, \
                             scope = 'net_eval') 
            
        
        #管理神經網路的parameters
        self.Actor_eval_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Actor/net_eval')
        
        
        #loss
        """
        算出 “神經網路輸出的動作機率”與 “實際動作”的cross entropy當作loss，但是更新的方向和力道就利用action
        reward來決定。例如，這一回合產生的所有動作組合如果得到很好的reward，那就應該讓神經網路的輸出機率更靠近實
        際輸出的結果，因此cross_entropy和action_reward相乘的到的loss就更大，更新力度就更大。相反的，這一回
        合產生的所有動作組合如果得到負的reward，那就應該讓神經網路輸出動作的機率更遠離實際輸出結果，在這樣的狀況
        下，cross_entropy和action_reward相乘的到的loss就會得到負的，神經網路的參數更新方向就會往反方向。
        """
        self.cross_entropy = tf.reduce_sum(-tf.log(self.act_proba)*self.real_action, axis=1)
        self.loss = tf.reduce_sum(self.cross_entropy*self.Vt)
 
        
        self.train = tf.train.RMSPropOptimizer(self.lr).minimize(self.loss, var_list=self.Actor_eval_params)
    
        self.sess.run(tf.global_variables_initializer()) #將神經網路初始化
    
    def write_memory(self, current_state, reward, action): #####
        
        action_one_hot = self.action_one_hot.copy()
        action_one_hot[action] = 1
        self.past_state.append(current_state)
        self.past_action.append(action_one_hot)
        self.past_reward.append(reward)
    
    
    def build_network(self, neuron_num, Trainable, scope): 
        with tf.variable_scope(scope):
            init_w = tf.random_normal_initializer(0., 0.3)
            init_b = tf.constant_initializer(0.1)
            
            x_h1 = tf.layers.dense(inputs = self.state_input, units = neuron_num, \
                   activation = tf.nn.tanh, kernel_initializer=init_w, \
                   bias_initializer=init_b, trainable=Trainable) 
            x_h2 = tf.layers.dense(inputs = self.state_input, units = neuron_num, \
                   activation = tf.nn.tanh, kernel_initializer=init_w, \
                   bias_initializer=init_b, trainable=Trainable)
            
            output = tf.layers.dense(inputs = x_h2, units = self.n_actions, \
                   activation = tf.nn.softmax, kernel_initializer=init_w, \
                   bias_initializer=init_b, trainable=Trainable)#輸出為個行為的機率，因此使用softmax
            
        
        return output #輸出‘不同動作’對應的Q值 
               
 
            
    def choose_action(self, current_state):
        
        act_proba = self.sess.run(self.act_proba, feed_dict={self.state_input: current_state[np.newaxis, :]})
        """
        根據神經網路輸出個動作的機率當作權重做隨機抽樣選出動作。一樣舉超級瑪莉的例子，如果輸出
        [上, 下, 左, 右]的機率分別為[0.3, 0.1, 0.2, 0.4]，那做隨機抽樣就分別有30%, 10%, 
        20%和40%的機率抽到上、下、左、右，因為這樣的做法已具有隨機性因此不需要用epsilon來控制
        行為的隨機程度來增加探索。
        """
        self.action = np.random.choice(range(act_proba.shape[1]), p=act_proba.ravel())  
   
        return self.action
    
    def learn(self): #####
        
        #用reward算出更新向量
        Vt = self.calculate_Vt(self.past_reward)
        #print(np.array(self.past_action).shape)
        #print(np.array(self.past_action))
        #將整個episode的資料放進來做更新
        self.sess.run(self.train, feed_dict={
             self.state_input: np.vstack(self.past_state),  # shape=[None, n_state]
             self.real_action: np.array(self.past_action),  # shape=[None, n_actions]
             self.Vt: np.array(Vt)  # shape=[None, ]
        })
        #更新完後將記憶庫清空
        self.past_state, self.past_action, self.past_reward = [], [], []    
    
    def calculate_Vt(self, reward):
        # discount episode rewards
        Vt = np.zeros_like(reward, dtype=np.float64)
        Vt_temp = 0
        for t in reversed(range(0, len(reward))):
            Vt_temp = reward[t] + Vt_temp * self.gamma
            Vt[t] = Vt_temp

        # normalize episode rewards
        
        Vt -= np.mean(Vt)
        Vt /= np.std(Vt)
        
        return Vt    
        
    def model_save(self, model_name):
        
        saver = tf.train.Saver()
        saver.save(self.sess, "saved_models/{}.ckpt".format(model_name))
    
    def model_restore(self, model_name):
        
        saver = tf.train.Saver()
        saver.restore(self.sess, "saved_models/{}.ckpt".format(model_name))

# %%
def training(save_model, model_name):
    step_record = []
    reward_record = []
    for episode in range(200):
        # initial environment並給出起始的state
        current_state = env.reset()
        step = 0
        total_reward = 0
        while True:
            # 產生環境視窗
            env.render()

            # 根據現在的狀態選擇動作
            action = RL.choose_action(current_state)

            # 產生動作和環境互動後產生下一個狀態、獎勵值及遊戲是否結束
            next_state, reward, done, _ = env.step(action)
            
            total_reward+= reward
            
            #這句可加可不加，只是怕因為machine變太強會玩很久不死，所以強迫結束遊戲
            if step > 10000:
                done = True
            
            # 將資訊存至記憶體中以便進行experience replay
            RL.write_memory(current_state, reward, action)
            

            # swap state
            current_state = next_state

            # break while loop when end of this episode
            if done:
                RL.learn()
                print('episode:{} steps:{} total reward:{}'.format(episode, step, total_reward))
                step_record.append(step)
                reward_record.append(total_reward)
                break
            step += 1

    # end of game
    if save_model:
        RL.model_save(model_name)
    print('game over')
    env.close()
    return step_record, reward_record

# %%
env = gym.make('CartPole-v0')
env.seed(1)     # reproducible, general Policy gradient has high variance
env = env.unwrapped
RL = Policy_Gradient(n_actions = 2, 
                   n_states = 4,
                   gamma = 0.99,
                   learning_rate = 0.01,
                 )
step_record, reward_record = training(save_model = True, model_name='PG_CartPole')
# Out:
# episode:0 steps:10 total reward:11.0
# episode:1 steps:11 total reward:12.0
# episode:2 steps:10 total reward:11.0
# episode:3 steps:9 total reward:10.0
# episode:4 steps:36 total reward:37.0
# episode:5 steps:18 total reward:19.0
# episode:6 steps:20 total reward:21.0
# episode:7 steps:26 total reward:27.0
# episode:8 steps:11 total reward:12.0
# episode:9 steps:14 total reward:15.0
# episode:10 steps:12 total reward:13.0
# episode:11 steps:13 total reward:14.0
# episode:12 steps:22 total reward:23.0
# episode:13 steps:10 total reward:11.0
# episode:14 steps:17 total reward:18.0
# episode:15 steps:11 total reward:12.0
# episode:16 steps:37 total reward:38.0
# episode:17 steps:16 total reward:17.0
# episode:18 steps:11 total reward:12.0
# episode:19 steps:28 total reward:29.0
# episode:20 steps:20 total reward:21.0
# episode:21 steps:32 total reward:33.0
# episode:22 steps:21 total reward:22.0
# episode:23 steps:23 total reward:24.0
# episode:24 steps:29 total reward:30.0
# episode:25 steps:24 total reward:25.0
# episode:26 steps:30 total reward:31.0
# episode:27 steps:26 total reward:27.0
# episode:28 steps:23 total reward:24.0
# episode:29 steps:12 total reward:13.0
# episode:30 steps:22 total reward:23.0
# episode:31 steps:106 total reward:107.0
# episode:32 steps:28 total reward:29.0
# episode:33 steps:21 total reward:22.0
# episode:34 steps:24 total reward:25.0
# episode:35 steps:47 total reward:48.0
# episode:36 steps:47 total reward:48.0
# episode:37 steps:17 total reward:18.0
# episode:38 steps:22 total reward:23.0
# episode:39 steps:44 total reward:45.0
# episode:40 steps:42 total reward:43.0
# episode:41 steps:46 total reward:47.0
# episode:42 steps:69 total reward:70.0
# episode:43 steps:24 total reward:25.0
# episode:44 steps:57 total reward:58.0
# episode:45 steps:41 total reward:42.0
# episode:46 steps:85 total reward:86.0
# episode:47 steps:31 total reward:32.0
# episode:48 steps:20 total reward:21.0
# episode:49 steps:65 total reward:66.0
# episode:50 steps:38 total reward:39.0
# episode:51 steps:21 total reward:22.0
# episode:52 steps:52 total reward:53.0
# episode:53 steps:23 total reward:24.0
# episode:54 steps:168 total reward:169.0
# episode:55 steps:112 total reward:113.0
# episode:56 steps:45 total reward:46.0
# episode:57 steps:31 total reward:32.0
# episode:58 steps:127 total reward:128.0
# episode:59 steps:55 total reward:56.0
# episode:60 steps:17 total reward:18.0
# episode:61 steps:82 total reward:83.0
# episode:62 steps:64 total reward:65.0
# episode:63 steps:23 total reward:24.0
# episode:64 steps:35 total reward:36.0
# episode:65 steps:106 total reward:107.0
# episode:66 steps:38 total reward:39.0
# episode:67 steps:20 total reward:21.0
# episode:68 steps:59 total reward:60.0
# episode:69 steps:559 total reward:560.0
# episode:70 steps:53 total reward:54.0
# episode:71 steps:210 total reward:211.0
# episode:72 steps:145 total reward:146.0
# episode:73 steps:102 total reward:103.0
# episode:74 steps:104 total reward:105.0
# episode:75 steps:185 total reward:186.0
# episode:76 steps:31 total reward:32.0
# episode:77 steps:261 total reward:262.0
# episode:78 steps:199 total reward:200.0
# episode:79 steps:143 total reward:144.0
# episode:80 steps:178 total reward:179.0
# episode:81 steps:120 total reward:121.0
# episode:82 steps:144 total reward:145.0
# episode:83 steps:98 total reward:99.0
# episode:84 steps:138 total reward:139.0
# episode:85 steps:97 total reward:98.0
# episode:86 steps:32 total reward:33.0
# episode:87 steps:71 total reward:72.0
# episode:88 steps:218 total reward:219.0
# episode:89 steps:202 total reward:203.0
# episode:90 steps:79 total reward:80.0
# episode:91 steps:71 total reward:72.0
# episode:92 steps:82 total reward:83.0
# episode:93 steps:183 total reward:184.0
# episode:94 steps:142 total reward:143.0
# episode:95 steps:52 total reward:53.0
# episode:96 steps:150 total reward:151.0
# episode:97 steps:169 total reward:170.0
# episode:98 steps:51 total reward:52.0
# episode:99 steps:180 total reward:181.0
# episode:100 steps:680 total reward:681.0
# episode:101 steps:182 total reward:183.0
# episode:102 steps:110 total reward:111.0
# episode:103 steps:126 total reward:127.0
# episode:104 steps:101 total reward:102.0
# episode:105 steps:129 total reward:130.0
# episode:106 steps:75 total reward:76.0
# episode:107 steps:58 total reward:59.0
# episode:108 steps:147 total reward:148.0
# episode:109 steps:186 total reward:187.0
# episode:110 steps:147 total reward:148.0
# episode:111 steps:141 total reward:142.0
# episode:112 steps:94 total reward:95.0
# episode:113 steps:354 total reward:355.0
# episode:114 steps:184 total reward:185.0
# episode:115 steps:212 total reward:213.0
# episode:116 steps:196 total reward:197.0
# episode:117 steps:417 total reward:418.0
# episode:118 steps:552 total reward:553.0
# episode:119 steps:232 total reward:233.0
# episode:120 steps:348 total reward:349.0
# episode:121 steps:154 total reward:155.0
# episode:122 steps:315 total reward:316.0
# episode:123 steps:118 total reward:119.0
# episode:124 steps:181 total reward:182.0
# episode:125 steps:164 total reward:165.0
# episode:126 steps:135 total reward:136.0
# episode:127 steps:171 total reward:172.0
# episode:128 steps:241 total reward:242.0
# episode:129 steps:176 total reward:177.0
# episode:130 steps:347 total reward:348.0
# episode:131 steps:182 total reward:183.0
# episode:132 steps:503 total reward:504.0
# episode:133 steps:118 total reward:119.0
# episode:134 steps:348 total reward:349.0
# episode:135 steps:1047 total reward:1048.0
# episode:136 steps:895 total reward:896.0
# episode:137 steps:672 total reward:673.0
# episode:138 steps:2326 total reward:2327.0
# episode:139 steps:377 total reward:378.0
# episode:140 steps:1337 total reward:1338.0
# episode:141 steps:323 total reward:324.0
# episode:142 steps:4343 total reward:4344.0
# episode:143 steps:1954 total reward:1955.0
# episode:144 steps:10001 total reward:10002.0
# episode:145 steps:1871 total reward:1872.0
# episode:146 steps:522 total reward:523.0
# episode:147 steps:1373 total reward:1374.0
# episode:148 steps:1202 total reward:1203.0
# episode:149 steps:1976 total reward:1977.0
# episode:150 steps:4359 total reward:4360.0
# episode:151 steps:6480 total reward:6481.0
# episode:152 steps:10001 total reward:10002.0
# episode:153 steps:7639 total reward:7640.0
# episode:154 steps:8408 total reward:8409.0
# episode:155 steps:10001 total reward:10002.0
# episode:156 steps:10001 total reward:10002.0
# episode:157 steps:3385 total reward:3386.0
# episode:158 steps:10001 total reward:10002.0
# episode:159 steps:10001 total reward:10002.0
# episode:160 steps:7290 total reward:7291.0
# episode:161 steps:5409 total reward:5410.0
# episode:162 steps:10001 total reward:10002.0
# episode:163 steps:10001 total reward:10002.0
# episode:164 steps:10001 total reward:10002.0
# episode:165 steps:10001 total reward:10002.0
# episode:166 steps:2323 total reward:2324.0
# episode:167 steps:2341 total reward:2342.0
# episode:168 steps:10001 total reward:10002.0
# episode:169 steps:10001 total reward:10002.0
# episode:170 steps:10001 total reward:10002.0
# episode:171 steps:10001 total reward:10002.0
# episode:172 steps:10001 total reward:10002.0
# episode:173 steps:1625 total reward:1626.0
# episode:174 steps:10001 total reward:10002.0
# episode:175 steps:1165 total reward:1166.0
# episode:176 steps:6565 total reward:6566.0
# episode:177 steps:10001 total reward:10002.0
# episode:178 steps:10001 total reward:10002.0
# episode:179 steps:10001 total reward:10002.0
# episode:180 steps:1476 total reward:1477.0
# episode:181 steps:2606 total reward:2607.0
# episode:182 steps:10001 total reward:10002.0
# episode:183 steps:10001 total reward:10002.0
# episode:184 steps:10001 total reward:10002.0
# episode:185 steps:10001 total reward:10002.0
# episode:186 steps:10001 total reward:10002.0
# episode:187 steps:3238 total reward:3239.0
# episode:188 steps:10001 total reward:10002.0
# episode:189 steps:10001 total reward:10002.0
# episode:190 steps:10001 total reward:10002.0
# episode:191 steps:10001 total reward:10002.0
# episode:192 steps:10001 total reward:10002.0
# episode:193 steps:10001 total reward:10002.0
# episode:194 steps:10001 total reward:10002.0
# episode:195 steps:1521 total reward:1522.0
# episode:196 steps:10001 total reward:10002.0
# episode:197 steps:10001 total reward:10002.0
# episode:198 steps:10001 total reward:10002.0
# episode:199 steps:10001 total reward:10002.0
# game over

# %%
reward_result = pd.DataFrame(reward_record)
reward_result.columns = ['Policy Gradient']
reward_result.plot()
plt.xlabel('episode')
plt.ylabel('Total Reward')
plt.show()
